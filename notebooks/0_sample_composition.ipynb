# %% [markdown]
# # 0_sample_composition
#
# Sample-composition summary for the 113-question human-study subset, including yes/no, count, and other free-text questions by operation and entity group.

# %%
from pathlib import Path
import sys
from IPython.display import display

_NOTEBOOK_DIR = Path.cwd()
if (_NOTEBOOK_DIR / "helpers.py").exists():
    sys.path.insert(0, str(_NOTEBOOK_DIR.parent))
elif (_NOTEBOOK_DIR / "notebooks" / "helpers.py").exists():
    sys.path.insert(0, str(_NOTEBOOK_DIR))

from notebooks.helpers import sample_composition_tables, write_sample_composition_table, pretty_print_path

# %%
overall, by_op, by_ent = sample_composition_tables()
display(overall)
display(by_op)
display(by_ent)

# %%
out = write_sample_composition_table()
print(pretty_print_path(out))
