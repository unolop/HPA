# %%
from glob import glob 
import pandas as pd 

for file in glob("/home/work/yuna/HPA/results/humans/all_results_20251202_112501/*/*.csv"): 
    print(file)
# Out:
# /home/work/yuna/HPA/results/humans/all_results_20251202_112501/0756a860_20251124_133827/answers.csv
# /home/work/yuna/HPA/results/humans/all_results_20251202_112501/218b2db5_20251126_084136/answers.csv
# /home/work/yuna/HPA/results/humans/all_results_20251202_112501/29127478_20251202_100107/answers.csv
# /home/work/yuna/HPA/results/humans/all_results_20251202_112501/3238ebaf_20251126_140604/answers.csv
# /home/work/yuna/HPA/results/humans/all_results_20251202_112501/5d843d39_20251127_141921/answers.csv
# /home/work/yuna/HPA/results/humans/all_results_20251202_112501/6b3a1a8d_20251125_135446/answers.csv
# /home/work/yuna/HPA/results/humans/all_results_20251202_112501/b9b2cb98_20251127_193952/answers.csv
# /home/work/yuna/HPA/results/humans/all_results_20251202_112501/d1548553_20251125_202324/answers.csv
# /home/work/yuna/HPA/results/humans/all_results_20251202_112501/dd0f9986_20251128_222537/answers.csv
