# %% [markdown]
# # S2 | Answer Distribution — Yes/No & Number
#
# Recovered from session 1 `A2_mmstar.ipynb` (commit `2bbcec7`), adapted to S2 data.
#
# Shows **normalized horizontal stacked bar charts** for each model group:
# - **Ground Truth** — VQA majority answer (`multiple_choice_answer`)
# - **Humans** — S2 study participants, variant C (original question)
# - **VLM** — full vision-language model (blind PNG passed)
# - **VLM decoder** — VLM weights, vision encoder bypassed
# - **Standalone LLM** — pure text LLM, nothink mode
# - **Standalone LLM (think)** — pure text LLM, think mode (Qwen3 only)
#
# **Section 1 — Blind condition**
# **Section 2 — Inst-blind condition**
#
# Two plots per section: yes/no distribution and number distribution.

# %%
import json
import os
import re
import sys
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict

sys.path.insert(0, '/home/david/Desktop/yuna/HPA/analysis')
from utils.vqa import VQAAnswerMapper, extract_number, bin_number

mapper = VQAAnswerMapper()
mapper._load()

BASE      = '/home/david/Desktop/yuna/HPA'
LOGIT_DIR = os.path.join(BASE, 'evaluation/logits')
HUMAN_DIR = os.path.join(BASE, 'evaluation/humans/by_participant')

# ── Model groups ──────────────────────────────────────────────────────────────
GROUPS = {
    'VLM': {
        'dir': os.path.join(LOGIT_DIR, 'vlm', 'pretrained'),
        'models': [
            'InternVL3_5-1B', 'InternVL3_5-2B', 'InternVL3_5-8B',
            'Qwen3-VL-2B-Instruct', 'Qwen3-VL-4B-Instruct', 'Qwen3-VL-8B-Instruct',
            'llava-1.5-7b-hf', 'llava-v1.6-mistral-7b-hf',
            'llava-v1.6-vicuna-7b-hf', 'llava-v1.6-vicuna-13b-hf',
        ],
        'clean_think': False,
    },
    'VLM decoder': {
        'dir': os.path.join(LOGIT_DIR, 'lm_decoder', 'pretrained'),
        'models': [
            'InternVL3_5-1B', 'InternVL3_5-2B', 'InternVL3_5-8B',
            'Qwen3-VL-2B-Instruct', 'Qwen3-VL-4B-Instruct', 'Qwen3-VL-8B-Instruct',
            'llava-1.5-7b-hf', 'llava-v1.6-mistral-7b-hf',
            'llava-v1.6-vicuna-7b-hf', 'llava-v1.6-vicuna-13b-hf',
        ],
        'clean_think': False,
    },
    'Standalone LLM': {
        'dir': os.path.join(LOGIT_DIR, 'backbone_nothink', 'pretrained'),
        'models': [
            'Qwen3-0.6B', 'Qwen3-1.7B', 'Qwen3-4B', 'Qwen3-8B', 'Qwen3-32B',
            'vicuna-7b-v1.5', 'vicuna-13b-v1.5', 'Mistral-7B-Instruct-v0.2',
        ],
        'clean_think': False,
    },
    'Standalone LLM (think)': {
        'dir': os.path.join(LOGIT_DIR, 'backbone_think', 'pretrained'),
        'models': [
            'Qwen3-0.6B', 'Qwen3-1.7B', 'Qwen3-4B', 'Qwen3-8B', 'Qwen3-32B',
        ],
        'clean_think': True,
    },
}

COND_FILES = {
    'blind':      'vqa_1k_control_blind.jsonl',
    'inst_blind': 'vqa_1k_control_inst_blind.jsonl',
}

SOURCE_ORDER = [
    'Ground Truth', 'Humans',
    'VLM', 'VLM decoder', 'Standalone LLM', 'Standalone LLM (think)',
]

CLEAN_THINK_RE = re.compile(r'<think>.*?</think>\s*', flags=re.DOTALL)
def strip_think(s):
    return CLEAN_THINK_RE.sub('', str(s or '')).strip()

print('Setup complete.')
# Out:
#    Loading VQA annotations from /home/david/Desktop/yuna/data/v2_mscoco_val2014_annotations.json...
#    ✓ Loaded 214354 VQA annotations
# Setup complete.

# %%
# ── Build answer_type lookup from VQA annotations ────────────────────────────
qid2atype = {
    int(qid): ann.get('answer_type', 'other')
    for qid, ann in mapper.annotations.items()
}
qid2gt = {
    int(qid): ann.get('multiple_choice_answer', '')
    for qid, ann in mapper.annotations.items()
}
print(f'Answer types: {pd.Series(qid2atype.values()).value_counts().to_dict()}')
# Out:
# Answer types: {'other': 105679, 'yes/no': 80541, 'number': 28134}

# %%
# ── Load model outputs per group × condition ──────────────────────────────────
# strip_think applied unconditionally — backbone_nothink files confirmed to still
# contain <think>...</think> tags despite the nothink template (~97-100% of lines).
model_rows = []
for group, cfg in GROUPS.items():
    for model in cfg['models']:
        for cond, fname in COND_FILES.items():
            path = os.path.join(cfg['dir'], model, fname)
            if not os.path.exists(path):
                continue
            with open(path) as f:
                for line in f:
                    if not line.strip(): continue
                    try:
                        ex = json.loads(line)
                    except json.JSONDecodeError:
                        continue
                    qid = int(ex['question_id'])
                    ga  = ex.get('generated_answers', {})
                    raw = strip_think(ga.get('question', ''))  # always strip
                    model_rows.append({
                        'qid':         qid,
                        'answer_type': qid2atype.get(qid, 'other'),
                        'source':      group,
                        'model':       model,
                        'condition':   cond,
                        'output':      raw.strip().lower(),
                    })

model_df = pd.DataFrame(model_rows)
print(f'Model rows: {len(model_df)}')
print(model_df.groupby(['source', 'condition']).size().unstack(fill_value=0))
# Out:
# Model rows: 65174
# condition               blind  inst_blind
# source
# Standalone LLM           8000        8000
# Standalone LLM (think)   4174        5000
# VLM                     10000       10000
# VLM decoder             10000       10000

# %%
# ── Load human answers (variant C = original question, inst_blind) ────────────
human_rows = []
for fpath in sorted(glob.glob(os.path.join(HUMAN_DIR, '*.json'))):
    with open(fpath) as f:
        p = json.load(f)
    for entry in p.get('answers', []):
        if entry.get('variant') != 'C':  # only original question variant
            continue
        qid = int(entry.get('question_id', 0))
        ans = entry.get('answer_text', '')
        human_rows.append({
            'qid': qid,
            'answer_type': qid2atype.get(qid, 'other'),
            'source': 'Humans',
            'output': str(ans).strip().lower(),
        })

human_df = pd.DataFrame(human_rows)
print(f'Human rows: {len(human_df)} from {len(glob.glob(os.path.join(HUMAN_DIR, "*.json")))} participants')
print(human_df.groupby('answer_type').size())
# Out:
# Human rows: 4576 from 36 participants
# answer_type
# number     947
# other     2332
# yes/no    1297
# dtype: int64

# %%
# ── Build GT rows + combine ───────────────────────────────────────────────────
all_qids = set(model_df['qid'].unique()) | set(human_df['qid'].unique())

gt_rows = []
for qid in all_qids:
    gt_rows.append({
        'qid':         qid,
        'answer_type': qid2atype.get(qid, 'other'),
        'source':      'Ground Truth',
        'condition':   'both',          # GT is condition-agnostic
        'output':      str(qid2gt.get(qid, '')).strip().lower(),
    })

gt_df = pd.DataFrame(gt_rows)

# Human rows have no explicit condition column — add one
human_df['condition'] = 'inst_blind'   # study was inst_blind

all_df = pd.concat([gt_df, human_df, model_df], ignore_index=True)
print(f'Total rows: {len(all_df)}')
print(all_df.groupby(['source', 'condition']).size().unstack(fill_value=0))
# Out:
# Total rows: 70750
# condition               blind  both  inst_blind
# source
# Ground Truth                0  1000           0
# Humans                      0     0        4576
# Standalone LLM           8000     0        8000
# Standalone LLM (think)   4174     0        5000
# VLM                     10000     0       10000
# VLM decoder             10000     0       10000

# %%
# ── Shared plot helpers ───────────────────────────────────────────────────────

def classify_yn(s):
    # strip trailing punctuation so "yes." / "no," etc. still match
    s = str(s).lower().strip().rstrip('.,!?;:')
    if s == 'yes' or s.startswith('yes '):  return 'yes'
    if s == 'no'  or s.startswith('no '):   return 'no'
    return 'others'

def normalize_output(s):
    """Lowercase, strip whitespace and trailing punctuation."""
    return str(s).lower().strip().rstrip('.,!?;:')

def make_yn_stack(df, condition):
    """Return normalized pivot for yes/no questions under a given condition."""
    sub = df[(df['answer_type'] == 'yes/no')].copy()
    mask_model = ~sub['source'].isin(['Ground Truth', 'Humans'])
    sub = sub[~mask_model | (sub['condition'] == condition)]

    sub['y/n'] = sub['output'].apply(classify_yn)
    sub['source'] = pd.Categorical(sub['source'], categories=SOURCE_ORDER, ordered=True)

    counts = sub.value_counts(['source', 'y/n']).reset_index(name='count')
    counts['proportion'] = counts.groupby('source')['count'].transform(lambda x: x / x.sum())
    stack = counts.pivot(index='source', columns='y/n', values='proportion').fillna(0)
    return stack.reindex(SOURCE_ORDER).dropna(how='all')

def make_num_stack(df, condition):
    """Return normalized pivot for number questions under a given condition."""
    sub = df[(df['answer_type'] == 'number')].copy()
    mask_model = ~sub['source'].isin(['Ground Truth', 'Humans'])
    sub = sub[~mask_model | (sub['condition'] == condition)]

    def classify_num(s):
        # strip trailing punctuation before extracting — handles "three." "none." etc.
        cleaned = normalize_output(s)
        n = extract_number(cleaned)
        return bin_number(n) if n is not None else 'others'

    sub['number_bin'] = sub['output'].apply(classify_num)
    sub['source'] = pd.Categorical(sub['source'], categories=SOURCE_ORDER, ordered=True)

    counts = sub.value_counts(['source', 'number_bin']).reset_index(name='count')
    counts['proportion'] = counts.groupby('source')['count'].transform(lambda x: x / x.sum())
    stack = counts.pivot(index='source', columns='number_bin', values='proportion').fillna(0)
    return stack.reindex(SOURCE_ORDER).dropna(how='all')

def plot_yn(stack_df, title=''):
    colors = {'yes': '#6BA292', 'no': '#C97A6A', 'others': '#B5B5B5'}
    cats   = [c for c in ['yes', 'no', 'others'] if c in stack_df.columns]
    n_rows = stack_df.shape[0]

    fig, ax = plt.subplots(figsize=(7, 0.8 * n_rows + 1.4))
    stack_df[cats].plot(kind='barh', stacked=True, ax=ax,
                        color=[colors[c] for c in cats], width=0.75)
    ax.invert_yaxis()   # read top-to-bottom: GT → Humans → VLM → VLM decoder → LLM → LLM(think)
    ax.set_xlim(0, 1)
    ax.set_ylabel('')
    ax.grid(False)
    for spine in ['top', 'right', 'left']:
        ax.spines[spine].set_visible(False)
    for i, src in enumerate(stack_df.index):
        cum = 0
        for cat in cats:
            val = stack_df.loc[src, cat]
            if val > 0.04:
                ax.text(cum + val / 2, i, f'{val*100:.0f}%',
                        ha='center', va='center', color='white', fontsize=10, fontweight='bold')
            cum += val
    ax.legend(loc='lower right', bbox_to_anchor=(0.72, -0.12), ncol=3, frameon=False)
    if title:
        ax.set_title(title, fontsize=12, fontweight='bold')
    plt.tight_layout()
    plt.show()

def plot_num(stack_df, title=''):
    colors = {
        '0': '#DADADA', '1': '#BFD7EA', '2\u20133': '#9EC1A3',
        '4\u20135': '#7FB3A2', '6\u201310': '#5C8D89',
        '11\u201320': '#4C6A92', '>20': '#8E5A5A', 'others': '#B5B5B5'
    }
    ORDER = ['0','1','2\u20133','4\u20135','6\u201310','11\u201320','>20','others']
    ORDER = [o for o in ORDER if o in stack_df.columns]
    n_rows = stack_df.shape[0]

    fig, ax = plt.subplots(figsize=(11, 0.8 * n_rows + 1.4))
    stack_df[ORDER].plot(kind='barh', stacked=True, ax=ax,
                         color=[colors[c] for c in ORDER], width=0.75)
    ax.invert_yaxis()   # read top-to-bottom: GT → Humans → VLM → VLM decoder → LLM → LLM(think)
    ax.set_xlim(0, 1)
    ax.set_ylabel('')
    ax.grid(False)
    for spine in ['top', 'right', 'left']:
        ax.spines[spine].set_visible(False)
    for i, src in enumerate(stack_df.index):
        cum = 0
        for cat in ORDER:
            val = stack_df.loc[src, cat] if cat in stack_df.columns else 0
            if val > 0.04:
                ax.text(cum + val / 2, i, f'{val*100:.0f}%',
                        ha='center', va='center', color='white', fontsize=10, fontweight='bold')
            cum += val
    ax.tick_params(axis='y', labelsize=11)
    ax.legend(bbox_to_anchor=(0.5, -0.08), loc='upper center',
              ncol=len(ORDER), frameon=False, fontsize=10)
    if title:
        ax.set_title(title, fontsize=12, fontweight='bold')
    plt.tight_layout()
    plt.show()

print('Plot helpers defined.')
# Out:
# Plot helpers defined.

# %% [markdown]
# ## Section 1 — Blind Condition

# %%
# ── Inspect Standalone LLM "others" answers ───────────────────────────────────
# Shows top output strings and raw samples to diagnose why they land in "others"

llm_blind = model_df[
    (model_df['source'] == 'Standalone LLM') &
    (model_df['condition'] == 'blind')
].copy()

for atype, classify_fn in [
    ('yes/no',  lambda x: classify_yn(x)),
    ('number',  lambda x: 'number' if extract_number(x) is not None else 'others'),
]:
    sub = llm_blind[llm_blind['answer_type'] == atype].copy()
    sub['class'] = sub['output'].apply(classify_fn)
    others = sub[sub['class'] == 'others']

    print(f'\n{"="*60}')
    print(f'  answer_type = {atype}  |  total={len(sub)}  others={len(others)} ({len(others)/len(sub)*100:.0f}%)')
    print(f'{"="*60}')

    # Top outputs overall
    print('\n── Top 20 output strings (all classes) ──')
    print(sub['output'].value_counts().head(20).to_string())

    # Per-model "others" rate
    print('\n── "others" rate per model ──')
    per_model = sub.groupby('model')['class'].apply(
        lambda x: (x == 'others').mean()
    ).sort_values(ascending=False)
    print(per_model.round(3).to_string())

    # Sample 10 "others" outputs with their question
    print('\n── Sample "others" outputs (blind, variant C) ──')
    sample = others.sample(min(10, len(others)), random_state=42)[['model', 'qid', 'output']]
    qid2q = {}
    for _, r in sample.iterrows():
        ann = mapper.annotations.get(int(r['qid']), {})
        qid2q[r['qid']] = ann.get('question', '?')
    sample = sample.copy()
    sample['question'] = sample['qid'].map(qid2q)
    sample['output_preview'] = sample['output'].str[:80]
    print(sample[['model', 'question', 'output_preview']].to_string(index=False))
# Out:
# ============================================================
#   answer_type = yes/no  |  total=3104  others=1906 (61%)
# ============================================================
#
# ── Top 20 output strings (all classes) ──
# output
# yes.                                                          869
#                                                               681
# no.                                                           282
# yes                                                            42
# possibly.                                                      41
# i cannot determine that based on the given information.        15
# unknown                                                        14
# sun                                                            10
# clear.                                                          8
# photo                                                           6
# water                                                           6
# on                                                              6
# bed                                                             5
# the answer is: yes.                                             5
# i cannot determine that based on the information provided.      5
# clear                                                           5
# cannot be determined.                                           4
# clean.                                                          4
# not all.                                                        4
# visible                                                         4
#
# ── "others" rate per model ──
# model
# Mistral-7B-Instruct-v0.2    1.000
# vicuna-7b-v1.5              1.000
# Qwen3-0.6B                  0.995
# vicuna-13b-v1.5             0.933
# Qwen3-1.7B                  0.580
# Qwen3-8B                    0.242
# Qwen3-4B                    0.088
# Qwen3-32B                   0.075
#
# ── Sample "others" outputs (blind, variant C) ──
#                    model question                                                                   output_preview
#          vicuna-13b-v1.5        ?
#               Qwen3-0.6B        ?                                                                              sky
# Mistral-7B-Instruct-v0.2        ? yes, the man is dining at home. (assuming the question refers to a specific man
# Mistral-7B-Instruct-v0.2        ? i cannot answer that question as i do not have the ability to see or interact wi
#               Qwen3-1.7B        ?                                                                 the sand is dry.
#          vicuna-13b-v1.5        ?
#               Qwen3-0.6B        ?                                                                          chinese
#               Qwen3-1.7B        ?                  it is not stated whether any of the men are driving the trucks.
#                 Qwen3-4B        ?                                                                            horse
# Mistral-7B-Instruct-v0.2        ? maybe. without additional context, it is impossible to determine if the referred
#
# ============================================================
#   answer_type = number  |  total=976  others=644 (66%)
# ============================================================
#
# ── Top 20 output strings (all classes) ──
# output
#             234
# unknown      46
# 1            35
# none.        25
# three.       23
# 3            23
# zero         22
# none         21
# three        13
# two.         10
# two           9
# four.         8
# one           6
# four          5
# 2             4
# unknown.      4
# one.          4
# five.         3
# stop          3
# 0             3
#
# ── "others" rate per model ──
# model
# vicuna-7b-v1.5              1.000
# vicuna-13b-v1.5             0.975
# Mistral-7B-Instruct-v0.2    0.902
# Qwen3-1.7B                  0.689
# Qwen3-0.6B                  0.672
# Qwen3-8B                    0.410
# Qwen3-4B                    0.344
# Qwen3-32B                   0.287
#
# ── Sample "others" outputs (blind, variant C) ──
#                    model question                                                                   output_preview
# Mistral-7B-Instruct-v0.2        ? the question does not provide enough context to provide an accurate answer. ther
# Mistral-7B-Instruct-v0.2        ?             the question does not provide enough context to determine an answer.
# Mistral-7B-Instruct-v0.2        ? to answer your question, i would need to see the image of the t-shirt in questio
#                Qwen3-32B        ?                                                                          unknown
#               Qwen3-0.6B        ?                                                                             face
# Mistral-7B-Instruct-v0.2        ? i cannot see or know the number of people walking on the sidewalk without visual
# Mistral-7B-Instruct-v0.2        ? i cannot see or count rolls of toilet paper as i do not have the ability to phys
#           vicuna-7b-v1.5        ?
#          vicuna-13b-v1.5        ?
#                 Qwen3-4B        ?                                                                          framed.

# %%
plot_yn(make_yn_stack(all_df, 'blind'), title='Yes / No Distribution — Blind')
# Out:
# /tmp/ipykernel_2885274/2137294272.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   counts['proportion'] = counts.groupby('source')['count'].transform(lambda x: x / x.sum())

# %%
plot_num(make_num_stack(all_df, 'blind'), title='Number Distribution — Blind')
# Out:
# /tmp/ipykernel_2885274/2137294272.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   counts['proportion'] = counts.groupby('source')['count'].transform(lambda x: x / x.sum())

# %% [markdown]
# ## Section 2 — Inst-Blind Condition

# %%
plot_yn(make_yn_stack(all_df, 'inst_blind'), title='Yes / No Distribution — Inst-Blind')
# Out:
# /tmp/ipykernel_2885274/2137294272.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   counts['proportion'] = counts.groupby('source')['count'].transform(lambda x: x / x.sum())

# %%
plot_num(make_num_stack(all_df, 'inst_blind'), title='Number Distribution — Inst-Blind')
# Out:
# /tmp/ipykernel_2885274/2137294272.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   counts['proportion'] = counts.groupby('source')['count'].transform(lambda x: x / x.sum())
