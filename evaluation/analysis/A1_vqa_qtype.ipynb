# %%
import re 
import seaborn as sns
import pandas as pd 
from utils.score import get_summary  
from utils.df import * 

sns.set_theme(
    style="whitegrid",
    context="paper",
    font="serif"
) 
    
def extract_size(text):
    if pd.isna(text): return 1.0 # Default fallback
    match = re.search(r'\((\d+(?:\.\d+)?)[Bb]\)', text)
    return float(match.group(1)) if match else 1.0
    
model_results = {} 
vqa_1k = get_summary('vqa_1k').drop_duplicates(subset=['condition', 'question_id', 'model'])
vqa_5k = get_summary('vqa_5k').drop_duplicates(subset=['condition', 'question_id', 'model']) 
vqa_5k.condition.unique()
# Out:
# 85
# 89
# array(['', 'blind', 'inst blind', 'sys inst blind'], dtype=object)

# %% [markdown]
# ## quadrant plots (high blind alignment + low MG)
#
# - identifying failure modes
# - qualitative discussion
# ```Example:
# “The negative relationship is most pronounced for ‘commonsense’ and ‘counting’ questions.”
# ```

# %%
import sys 
sys.path.append('..')
from score_humans import get_vqa_mapper, VQAAnswerMapper 

vqa_answers = get_vqa_mapper()  
vqamapper = VQAAnswerMapper()
vqamapper._load()
vqa_annot = vqamapper.annotations 

human_vqa = pd.read_json('/home/work/yuna/HPA/evaluation/scored/humans/human_vqa_per_question.json')
human_vqa['model'] = "Humans" 
human_vqa['meta_model'] = "humans"
human_vqa['condition'] = "inst blind" 
human_vqa.rename(columns={"mean_accuracy": 'correct', 'qid': 'question_id'}, inplace=True) 
human_vqa['correct'] = pd.to_numeric((human_vqa['correct'] * 100).round(1) , errors='coerce')
human_vqa['answer_similarity'] = pd.to_numeric((human_vqa['answer_similarity'] * 100).round(1) , errors='coerce')
human_vqa['question_type'] = human_vqa['question_id'].map(lambda qid: vqa_annot[int(qid)]['question_type'] if int(qid) in vqa_annot else None)
human_vqa['answer_type'] = human_vqa['question_id'].map(lambda qid: vqa_annot[int(qid)]['answer_type'] if int(qid) in vqa_annot else None)
human_vqa = human_vqa.drop_duplicates(subset=[ 'participant_id', 'question_id'])
human_vqa = human_vqa[human_vqa['participant_id'] != '13f54aa2_20251204_125847']
human_vqa.groupby('participant_id')['question_id'].nunique()
# Out:
#    Loading VQA annotations from /home/work/yuna/VLMEval/data/v2_mscoco_val2014_annotations.json...
#    ✓ Loaded 214354 VQA annotations
# participant_id
# 02f952bb_20251210_230336            374
# 0756a860_20251124_133827            374
# 14d2420f_20251208_150302            374
# 218b2db5_20251126_084136            374
# 29127478_20251202_100107            374
# 2e184452_20251205_141511_cleaned    374
# 3238ebaf_20251126_140604            374
# 3a36e078_20251205_225238            374
# 5d843d39_20251127_141921            374
# 60de6bd6_20251210_170035            374
# 6b3a1a8d_20251125_135446            374
# 73df43f3_20251204_210431            374
# 74d408e5_20251213_134035            374
# 825ff3e9_20251210_192335            374
# 9c5d09f3_20251209_121033            374
# a5909497_20251211_232822            374
# b9b2cb98_20251127_193952            374
# d1548553_20251125_202324            370
# dd0f9986_20251128_222537            374
# f616d5c7_20251203_212223            374
# Name: question_id, dtype: int64

# %%
qids = human_vqa.question_id.unique()
model_vqa = vqa_1k[(vqa_1k['question_id'].isin(qids)) & (vqa_1k['condition'] == 'inst blind')].replace(model_name_map)
print(vqa_1k.condition.unique(),'condition mapped to-> ', model_vqa.condition.unique())
pmd = model_vqa[model_vqa['model'].isin(model_name_map.values())]  # pretrained models df on vqa blind data  

### combine human and model 
hm = pd.concat([model_vqa, human_vqa]) 
hm['model'] = hm['model']  # pt.to_csv(f'./tables/vqa_human_comparison.csv')      

### filtered datafrmes 
df = hm[['meta_model', 'question_id', 'answer_type', 'question_type', 'model', 'question', 'answer', 'output', 'correct', 'answer_similarity']]
human_df = df[df['model'] == 'Humans'] # .dropna(axis=1)   
humanavg= human_df.groupby(['question_id', 'answer_type', 'question_type']).mean(numeric_only=True).reset_index() 
model_df = df[df['model'] != 'Humans'] 
mhavg = pd.merge( model_df, humanavg, on=['question_id', 'answer_type', 'question_type'], how='left', suffixes=('_model', '_human') )# .dropna(axis=1)
# mhavg.groupby(['model']).count().head() # it has to be all 374 questions for each model 
# len(qids), # model_vqa.groupby(['model', 'question_id']).count()    

### human and model 
human_cols = human_vqa.participant_id.unique()
model_cols = pmd.model.unique() 

len(human_cols), len(model_cols)
# Out:
# ['' 'blind' 'inst blind'] condition mapped to->  ['inst blind']

# %%
from utils.corr import get_all_cm, get_agreements, transform_corr_table, plot_unified_agreement_heatmap

def result_to_df(res):
    # Extract everything except 'corr_mat'
    data = {k: v for k, v in res.items() if k != 'corr_mat'}
    return pd.DataFrame([data])

res_HH, res_MM, res_HM  = get_agreements(human_vqa, pmd, n_boot=0)  # accuarcy 
corr_mat = get_all_cm(res_HH, res_MM, res_HM )
plot_unified_agreement_heatmap(corr_mat, human_cols, model_cols , 'Human–Model Agreement (Accuracy)', '/home/work/yuna/HPA/evaluation/analysis/figures/agreement-acc.png') 
acc = pd.concat([result_to_df(res_HH), result_to_df(res_MM), result_to_df(res_HM)]) 

res_HH, res_MM, res_HM  =  get_agreements(human_vqa, model_vqa, 'answer_similarity', n_boot=0) 
corr_mat = get_all_cm(res_HH, res_MM, res_HM ) 
acc = pd.concat([acc, result_to_df(res_HH), result_to_df(res_MM), result_to_df(res_HM)])
plot_unified_agreement_heatmap(corr_mat, human_cols, model_cols , 'Human–Model Agreement (Emb Similarity)', '/home/work/yuna/HPA/evaluation/analysis/figures/agreement-sim.png') 
transform_corr_table(acc).to_latex('./tables/3_spearman-interrater.tex', float_format="%.3f")

# %%
corr_mat
# Out:
#                                   02f952bb_20251210_230336  \
# 02f952bb_20251210_230336                          1.000000
# 0756a860_20251124_133827                          0.541967
# 14d2420f_20251208_150302                          0.487763
# 218b2db5_20251126_084136                          0.558040
# 29127478_20251202_100107                          0.578543
# 2e184452_20251205_141511_cleaned                  0.549370
# 3238ebaf_20251126_140604                          0.501305
# 3a36e078_20251205_225238                          0.609235
# 5d843d39_20251127_141921                          0.574173
# 60de6bd6_20251210_170035                          0.481561
# 6b3a1a8d_20251125_135446                          0.619753
# 73df43f3_20251204_210431                          0.579448
# 74d408e5_20251213_134035                          0.555080
# 825ff3e9_20251210_192335                          0.473927
# 9c5d09f3_20251209_121033                          0.608778
# a5909497_20251211_232822                          0.496924
# b9b2cb98_20251127_193952                          0.507720
# d1548553_20251125_202324                          0.507190
# dd0f9986_20251128_222537                          0.591150
# f616d5c7_20251203_212223                          0.573150
# InternVL 3.5 (1B)                                 0.453623
# InternVL 3.5 (2B)                                 0.445722
# InternVL 3.5 (4B)                                 0.470306
# InternVL 3.5 (8B)                                 0.494680
# LLaVA-v1.5 (7B)                                   0.367050
# LLaVA-v1.6-Mistral (7B)                           0.366344
# LLaVA-v1.6-Vicuna (7B)                            0.337978
# Qwen3-VL (2B)                                     0.403435
# Qwen3-VL (4B)                                     0.436167
# Qwen3-VL (8B)                                     0.409653
#
#                                   0756a860_20251124_133827  \
# 02f952bb_20251210_230336                          0.541967
# 0756a860_20251124_133827                          1.000000
# 14d2420f_20251208_150302                          0.493429
# 218b2db5_20251126_084136                          0.613397
# 29127478_20251202_100107                          0.594253
# 2e184452_20251205_141511_cleaned                  0.552197
# 3238ebaf_20251126_140604                          0.567047
# 3a36e078_20251205_225238                          0.610795
# 5d843d39_20251127_141921                          0.584023
# 60de6bd6_20251210_170035                          0.584791
# 6b3a1a8d_20251125_135446                          0.595018
# 73df43f3_20251204_210431                          0.525975
# 74d408e5_20251213_134035                          0.622583
# 825ff3e9_20251210_192335                          0.555155
# 9c5d09f3_20251209_121033                          0.568620
# a5909497_20251211_232822                          0.576651
# b9b2cb98_20251127_193952                          0.431707
# d1548553_20251125_202324                          0.454379
# dd0f9986_20251128_222537                          0.595882
# f616d5c7_20251203_212223                          0.607622
# InternVL 3.5 (1B)                                 0.474028
# InternVL 3.5 (2B)                                 0.518279
# InternVL 3.5 (4B)                                 0.515227
# InternVL 3.5 (8B)                                 0.516182
# LLaVA-v1.5 (7B)                                   0.485723
# LLaVA-v1.6-Mistral (7B)                           0.451334
# LLaVA-v1.6-Vicuna (7B)                            0.447645
# Qwen3-VL (2B)                                     0.513760
# Qwen3-VL (4B)                                     0.507499
# Qwen3-VL (8B)                                     0.530005
#
#                                   14d2420f_20251208_150302  \
# 02f952bb_20251210_230336                          0.487763
# 0756a860_20251124_133827                          0.493429
# 14d2420f_20251208_150302                          1.000000
# 218b2db5_20251126_084136                          0.561066
# 29127478_20251202_100107                          0.630058
# 2e184452_20251205_141511_cleaned                  0.522487
# 3238ebaf_20251126_140604                          0.517981
# 3a36e078_20251205_225238                          0.574717
# 5d843d39_20251127_141921                          0.513495
# 60de6bd6_20251210_170035                          0.532213
# 6b3a1a8d_20251125_135446                          0.620783
# 73df43f3_20251204_210431                          0.507643
# 74d408e5_20251213_134035                          0.529455
# 825ff3e9_20251210_192335                          0.542451
# 9c5d09f3_20251209_121033                          0.577373
# a5909497_20251211_232822                          0.494419
# b9b2cb98_20251127_193952                          0.493876
# d1548553_20251125_202324                          0.461038
# dd0f9986_20251128_222537                          0.540941
# f616d5c7_20251203_212223                          0.568494
# InternVL 3.5 (1B)                                 0.458344
# InternVL 3.5 (2B)                                 0.463550
# InternVL 3.5 (4B)                                 0.542932
# InternVL 3.5 (8B)                                 0.520429
# LLaVA-v1.5 (7B)                                   0.379770
# LLaVA-v1.6-Mistral (7B)                           0.375005
# LLaVA-v1.6-Vicuna (7B)                            0.387281
# Qwen3-VL (2B)                                     0.362049
# Qwen3-VL (4B)                                     0.494478
# Qwen3-VL (8B)                                     0.491694
#
#                                   218b2db5_20251126_084136  \
# 02f952bb_20251210_230336                          0.558040
# 0756a860_20251124_133827                          0.613397
# 14d2420f_20251208_150302                          0.561066
# 218b2db5_20251126_084136                          1.000000
# 29127478_20251202_100107                          0.642133
# 2e184452_20251205_141511_cleaned                  0.574101
# 3238ebaf_20251126_140604                          0.651382
# 3a36e078_20251205_225238                          0.665192
# 5d843d39_20251127_141921                          0.659526
# 60de6bd6_20251210_170035                          0.599802
# 6b3a1a8d_20251125_135446                          0.694406
# 73df43f3_20251204_210431                          0.619351
# 74d408e5_20251213_134035                          0.569753
# 825ff3e9_20251210_192335                          0.564924
# 9c5d09f3_20251209_121033                          0.665117
# a5909497_20251211_232822                          0.554074
# b9b2cb98_20251127_193952                          0.534942
# d1548553_20251125_202324                          0.582101
# dd0f9986_20251128_222537                          0.609156
# f616d5c7_20251203_212223                          0.676727
# InternVL 3.5 (1B)                                 0.515791
# InternVL 3.5 (2B)                                 0.474321
# InternVL 3.5 (4B)                                 0.575352
# InternVL 3.5 (8B)                                 0.634193
# LLaVA-v1.5 (7B)                                   0.380252
# LLaVA-v1.6-Mistral (7B)                           0.355882
# LLaVA-v1.6-Vicuna (7B)                            0.376064
# Qwen3-VL (2B)                                     0.433287
# Qwen3-VL (4B)                                     0.518308
# Qwen3-VL (8B)                                     0.505468
#
#                                   29127478_20251202_100107  \
# 02f952bb_20251210_230336                          0.578543
# 0756a860_20251124_133827                          0.594253
# 14d2420f_20251208_150302                          0.630058
# 218b2db5_20251126_084136                          0.642133
# 29127478_20251202_100107                          1.000000
# 2e184452_20251205_141511_cleaned                  0.639000
# 3238ebaf_20251126_140604                          0.606784
# 3a36e078_20251205_225238                          0.655063
# 5d843d39_20251127_141921                          0.634126
# 60de6bd6_20251210_170035                          0.622292
# 6b3a1a8d_20251125_135446                          0.694447
# 73df43f3_20251204_210431                          0.633690
# 74d408e5_20251213_134035                          0.587049
# 825ff3e9_20251210_192335                          0.553858
# 9c5d09f3_20251209_121033                          0.624741
# a5909497_20251211_232822                          0.553407
# b9b2cb98_20251127_193952                          0.509216
# d1548553_20251125_202324                          0.537326
# dd0f9986_20251128_222537                          0.651609
# f616d5c7_20251203_212223                          0.610919
# InternVL 3.5 (1B)                                 0.557466
# InternVL 3.5 (2B)                                 0.517700
# InternVL 3.5 (4B)                                 0.569028
# InternVL 3.5 (8B)                                 0.608227
# LLaVA-v1.5 (7B)                                   0.425291
# LLaVA-v1.6-Mistral (7B)                           0.437190
# LLaVA-v1.6-Vicuna (7B)                            0.407536
# Qwen3-VL (2B)                                     0.460862
# Qwen3-VL (4B)                                     0.491655
# Qwen3-VL (8B)                                     0.509659
#
#                                   2e184452_20251205_141511_cleaned  \
# 02f952bb_20251210_230336                                  0.549370
# 0756a860_20251124_133827                                  0.552197
# 14d2420f_20251208_150302                                  0.522487
# 218b2db5_20251126_084136                                  0.574101
# 29127478_20251202_100107                                  0.639000
# 2e184452_20251205_141511_cleaned                          1.000000
# 3238ebaf_20251126_140604                                  0.574164
# 3a36e078_20251205_225238                                  0.555814
# 5d843d39_20251127_141921                                  0.608930
# 60de6bd6_20251210_170035                                  0.547174
# 6b3a1a8d_20251125_135446                                  0.642059
# 73df43f3_20251204_210431                                  0.604379
# 74d408e5_20251213_134035                                  0.623086
# 825ff3e9_20251210_192335                                  0.539849
# 9c5d09f3_20251209_121033                                  0.608017
# a5909497_20251211_232822                                  0.530901
# b9b2cb98_20251127_193952                                  0.445793
# d1548553_20251125_202324                                  0.494010
# dd0f9986_20251128_222537                                  0.643331
# f616d5c7_20251203_212223                                  0.570447
# InternVL 3.5 (1B)                                         0.420146
# InternVL 3.5 (2B)                                         0.506723
# InternVL 3.5 (4B)                                         0.510576
# InternVL 3.5 (8B)                                         0.536439
# LLaVA-v1.5 (7B)                                           0.396047
# LLaVA-v1.6-Mistral (7B)                                   0.416440
# LLaVA-v1.6-Vicuna (7B)                                    0.357818
# Qwen3-VL (2B)                                             0.431820
# Qwen3-VL (4B)                                             0.482921
# Qwen3-VL (8B)                                             0.513859
#
#                                   3238ebaf_20251126_140604  \
# 02f952bb_20251210_230336                          0.501305
# 0756a860_20251124_133827                          0.567047
# 14d2420f_20251208_150302                          0.517981
# 218b2db5_20251126_084136                          0.651382
# 29127478_20251202_100107                          0.606784
# 2e184452_20251205_141511_cleaned                  0.574164
# 3238ebaf_20251126_140604                          1.000000
# 3a36e078_20251205_225238                          0.592024
# 5d843d39_20251127_141921                          0.641597
# 60de6bd6_20251210_170035                          0.463509
# 6b3a1a8d_20251125_135446                          0.637400
# 73df43f3_20251204_210431                          0.579966
# 74d408e5_20251213_134035                          0.514988
# 825ff3e9_20251210_192335                          0.584366
# 9c5d09f3_20251209_121033                          0.616340
# a5909497_20251211_232822                          0.488689
# b9b2cb98_20251127_193952                          0.454555
# d1548553_20251125_202324                          0.558671
# dd0f9986_20251128_222537                          0.607383
# f616d5c7_20251203_212223                          0.660916
# InternVL 3.5 (1B)                                 0.502296
# InternVL 3.5 (2B)                                 0.364564
# InternVL 3.5 (4B)                                 0.581219
# InternVL 3.5 (8B)                                 0.690405
# LLaVA-v1.5 (7B)                                   0.212769
# LLaVA-v1.6-Mistral (7B)                           0.254685
# LLaVA-v1.6-Vicuna (7B)                            0.260768
# Qwen3-VL (2B)                                     0.308816
# Qwen3-VL (4B)                                     0.497238
# Qwen3-VL (8B)                                     0.493736
#
#                                   3a36e078_20251205_225238  \
# 02f952bb_20251210_230336                          0.609235
# 0756a860_20251124_133827                          0.610795
# 14d2420f_20251208_150302                          0.574717
# 218b2db5_20251126_084136                          0.665192
# 29127478_20251202_100107                          0.655063
# 2e184452_20251205_141511_cleaned                  0.555814
# 3238ebaf_20251126_140604                          0.592024
# 3a36e078_20251205_225238                          1.000000
# 5d843d39_20251127_141921                          0.615019
# 60de6bd6_20251210_170035                          0.582081
# 6b3a1a8d_20251125_135446                          0.720588
# 73df43f3_20251204_210431                          0.581234
# 74d408e5_20251213_134035                          0.545001
# 825ff3e9_20251210_192335                          0.499470
# 9c5d09f3_20251209_121033                          0.699321
# a5909497_20251211_232822                          0.563954
# b9b2cb98_20251127_193952                          0.548381
# d1548553_20251125_202324                          0.542728
# dd0f9986_20251128_222537                          0.647868
# f616d5c7_20251203_212223                          0.657259
# InternVL 3.5 (1B)                                 0.535995
# InternVL 3.5 (2B)                                 0.490904
# InternVL 3.5 (4B)                                 0.563891
# InternVL 3.5 (8B)                                 0.592023
# LLaVA-v1.5 (7B)                                   0.388712
# LLaVA-v1.6-Mistral (7B)                           0.383495
# LLaVA-v1.6-Vicuna (7B)                            0.400588
# Qwen3-VL (2B)                                     0.442315
# Qwen3-VL (4B)                                     0.530505
# Qwen3-VL (8B)                                     0.546360
#
#                                   5d843d39_20251127_141921  \
# 02f952bb_20251210_230336                          0.574173
# 0756a860_20251124_133827                          0.584023
# 14d2420f_20251208_150302                          0.513495
# 218b2db5_20251126_084136                          0.659526
# 29127478_20251202_100107                          0.634126
# 2e184452_20251205_141511_cleaned                  0.608930
# 3238ebaf_20251126_140604                          0.641597
# 3a36e078_20251205_225238                          0.615019
# 5d843d39_20251127_141921                          1.000000
# 60de6bd6_20251210_170035                          0.533196
# 6b3a1a8d_20251125_135446                          0.707191
# 73df43f3_20251204_210431                          0.590815
# 74d408e5_20251213_134035                          0.583413
# 825ff3e9_20251210_192335                          0.528681
# 9c5d09f3_20251209_121033                          0.615915
# a5909497_20251211_232822                          0.546884
# b9b2cb98_20251127_193952                          0.549638
# d1548553_20251125_202324                          0.562584
# dd0f9986_20251128_222537                          0.643779
# f616d5c7_20251203_212223                          0.606700
# InternVL 3.5 (1B)                                 0.517498
# InternVL 3.5 (2B)                                 0.467213
# InternVL 3.5 (4B)                                 0.561335
# InternVL 3.5 (8B)                                 0.599508
# LLaVA-v1.5 (7B)                                   0.338492
# LLaVA-v1.6-Mistral (7B)                           0.346924
# LLaVA-v1.6-Vicuna (7B)                            0.387263
# Qwen3-VL (2B)                                     0.383274
# Qwen3-VL (4B)                                     0.487515
# Qwen3-VL (8B)                                     0.478166
#
#                                   60de6bd6_20251210_170035  ...  \
# 02f952bb_20251210_230336                          0.481561  ...
# 0756a860_20251124_133827                          0.584791  ...
# 14d2420f_20251208_150302                          0.532213  ...
# 218b2db5_20251126_084136                          0.599802  ...
# 29127478_20251202_100107                          0.622292  ...
# 2e184452_20251205_141511_cleaned                  0.547174  ...
# 3238ebaf_20251126_140604                          0.463509  ...
# 3a36e078_20251205_225238                          0.582081  ...
# 5d843d39_20251127_141921                          0.533196  ...
# 60de6bd6_20251210_170035                          1.000000  ...
# 6b3a1a8d_20251125_135446                          0.664114  ...
# 73df43f3_20251204_210431                          0.573217  ...
# 74d408e5_20251213_134035                          0.545426  ...
# 825ff3e9_20251210_192335                          0.558166  ...
# 9c5d09f3_20251209_121033                          0.648171  ...
# a5909497_20251211_232822                          0.516265  ...
# b9b2cb98_20251127_193952                          0.502396  ...
# d1548553_20251125_202324                          0.443668  ...
# dd0f9986_20251128_222537                          0.604202  ...
# f616d5c7_20251203_212223                          0.540640  ...
# InternVL 3.5 (1B)                                 0.567482  ...
# InternVL 3.5 (2B)                                 0.675814  ...
# InternVL 3.5 (4B)                                 0.538610  ...
# InternVL 3.5 (8B)                                 0.496776  ...
# LLaVA-v1.5 (7B)                                   0.583461  ...
# LLaVA-v1.6-Mistral (7B)                           0.565860  ...
# LLaVA-v1.6-Vicuna (7B)                            0.561077  ...
# Qwen3-VL (2B)                                     0.637089  ...
# Qwen3-VL (4B)                                     0.528278  ...
# Qwen3-VL (8B)                                     0.559495  ...
#
#                                   InternVL 3.5 (1B)  InternVL 3.5 (2B)  \
# 02f952bb_20251210_230336                   0.453623           0.445722
# 0756a860_20251124_133827                   0.474028           0.518279
# 14d2420f_20251208_150302                   0.458344           0.463550
# 218b2db5_20251126_084136                   0.515791           0.474321
# 29127478_20251202_100107                   0.557466           0.517700
# 2e184452_20251205_141511_cleaned           0.420146           0.506723
# 3238ebaf_20251126_140604                   0.502296           0.364564
# 3a36e078_20251205_225238                   0.535995           0.490904
# 5d843d39_20251127_141921                   0.517498           0.467213
# 60de6bd6_20251210_170035                   0.567482           0.675814
# 6b3a1a8d_20251125_135446                   0.585781           0.594384
# 73df43f3_20251204_210431                   0.516689           0.546115
# 74d408e5_20251213_134035                   0.403311           0.581009
# 825ff3e9_20251210_192335                   0.518419           0.521079
# 9c5d09f3_20251209_121033                   0.579482           0.566723
# a5909497_20251211_232822                   0.457512           0.480382
# b9b2cb98_20251127_193952                   0.451608           0.477195
# d1548553_20251125_202324                   0.390180           0.320153
# dd0f9986_20251128_222537                   0.561519           0.507686
# f616d5c7_20251203_212223                   0.534532           0.507121
# InternVL 3.5 (1B)                          1.000000           0.620348
# InternVL 3.5 (2B)                          0.620348           1.000000
# InternVL 3.5 (4B)                          0.598695           0.579118
# InternVL 3.5 (8B)                          0.539601           0.505224
# LLaVA-v1.5 (7B)                            0.479684           0.794447
# LLaVA-v1.6-Mistral (7B)                    0.486152           0.770474
# LLaVA-v1.6-Vicuna (7B)                     0.504410           0.765840
# Qwen3-VL (2B)                              0.556328           0.813897
# Qwen3-VL (4B)                              0.557370           0.643002
# Qwen3-VL (8B)                              0.552500           0.675390
#
#                                   InternVL 3.5 (4B)  InternVL 3.5 (8B)  \
# 02f952bb_20251210_230336                   0.470306           0.494680
# 0756a860_20251124_133827                   0.515227           0.516182
# 14d2420f_20251208_150302                   0.542932           0.520429
# 218b2db5_20251126_084136                   0.575352           0.634193
# 29127478_20251202_100107                   0.569028           0.608227
# 2e184452_20251205_141511_cleaned           0.510576           0.536439
# 3238ebaf_20251126_140604                   0.581219           0.690405
# 3a36e078_20251205_225238                   0.563891           0.592023
# 5d843d39_20251127_141921                   0.561335           0.599508
# 60de6bd6_20251210_170035                   0.538610           0.496776
# 6b3a1a8d_20251125_135446                   0.588553           0.647151
# 73df43f3_20251204_210431                   0.607712           0.553150
# 74d408e5_20251213_134035                   0.513419           0.484483
# 825ff3e9_20251210_192335                   0.574719           0.539106
# 9c5d09f3_20251209_121033                   0.596028           0.616060
# a5909497_20251211_232822                   0.480709           0.456179
# b9b2cb98_20251127_193952                   0.430214           0.459317
# d1548553_20251125_202324                   0.369453           0.492490
# dd0f9986_20251128_222537                   0.596876           0.601077
# f616d5c7_20251203_212223                   0.657833           0.646850
# InternVL 3.5 (1B)                          0.598695           0.539601
# InternVL 3.5 (2B)                          0.579118           0.505224
# InternVL 3.5 (4B)                          1.000000           0.681834
# InternVL 3.5 (8B)                          0.681834           1.000000
# LLaVA-v1.5 (7B)                            0.460507           0.368180
# LLaVA-v1.6-Mistral (7B)                    0.486411           0.418971
# LLaVA-v1.6-Vicuna (7B)                     0.463335           0.410632
# Qwen3-VL (2B)                              0.544171           0.461871
# Qwen3-VL (4B)                              0.661918           0.681568
# Qwen3-VL (8B)                              0.665219           0.653572
#
#                                   LLaVA-v1.5 (7B)  LLaVA-v1.6-Mistral (7B)  \
# 02f952bb_20251210_230336                 0.367050                 0.366344
# 0756a860_20251124_133827                 0.485723                 0.451334
# 14d2420f_20251208_150302                 0.379770                 0.375005
# 218b2db5_20251126_084136                 0.380252                 0.355882
# 29127478_20251202_100107                 0.425291                 0.437190
# 2e184452_20251205_141511_cleaned         0.396047                 0.416440
# 3238ebaf_20251126_140604                 0.212769                 0.254685
# 3a36e078_20251205_225238                 0.388712                 0.383495
# 5d843d39_20251127_141921                 0.338492                 0.346924
# 60de6bd6_20251210_170035                 0.583461                 0.565860
# 6b3a1a8d_20251125_135446                 0.435107                 0.429419
# 73df43f3_20251204_210431                 0.471386                 0.436730
# 74d408e5_20251213_134035                 0.486125                 0.492350
# 825ff3e9_20251210_192335                 0.406189                 0.440614
# 9c5d09f3_20251209_121033                 0.446475                 0.455746
# a5909497_20251211_232822                 0.403965                 0.409675
# b9b2cb98_20251127_193952                 0.383110                 0.365786
# d1548553_20251125_202324                 0.254613                 0.269579
# dd0f9986_20251128_222537                 0.449652                 0.451771
# f616d5c7_20251203_212223                 0.378615                 0.410580
# InternVL 3.5 (1B)                        0.479684                 0.486152
# InternVL 3.5 (2B)                        0.794447                 0.770474
# InternVL 3.5 (4B)                        0.460507                 0.486411
# InternVL 3.5 (8B)                        0.368180                 0.418971
# LLaVA-v1.5 (7B)                          1.000000                 0.846908
# LLaVA-v1.6-Mistral (7B)                  0.846908                 1.000000
# LLaVA-v1.6-Vicuna (7B)                   0.826761                 0.840475
# Qwen3-VL (2B)                            0.771359                 0.749105
# Qwen3-VL (4B)                            0.545568                 0.639263
# Qwen3-VL (8B)                            0.571087                 0.652993
#
#                                   LLaVA-v1.6-Vicuna (7B)  Qwen3-VL (2B)  \
# 02f952bb_20251210_230336                        0.337978       0.403435
# 0756a860_20251124_133827                        0.447645       0.513760
# 14d2420f_20251208_150302                        0.387281       0.362049
# 218b2db5_20251126_084136                        0.376064       0.433287
# 29127478_20251202_100107                        0.407536       0.460862
# 2e184452_20251205_141511_cleaned                0.357818       0.431820
# 3238ebaf_20251126_140604                        0.260768       0.308816
# 3a36e078_20251205_225238                        0.400588       0.442315
# 5d843d39_20251127_141921                        0.387263       0.383274
# 60de6bd6_20251210_170035                        0.561077       0.637089
# 6b3a1a8d_20251125_135446                        0.469119       0.499544
# 73df43f3_20251204_210431                        0.444025       0.476599
# 74d408e5_20251213_134035                        0.483189       0.551756
# 825ff3e9_20251210_192335                        0.415603       0.461667
# 9c5d09f3_20251209_121033                        0.415770       0.464262
# a5909497_20251211_232822                        0.413099       0.401214
# b9b2cb98_20251127_193952                        0.332931       0.384119
# d1548553_20251125_202324                        0.272787       0.263636
# dd0f9986_20251128_222537                        0.425258       0.464820
# f616d5c7_20251203_212223                        0.385735       0.440275
# InternVL 3.5 (1B)                               0.504410       0.556328
# InternVL 3.5 (2B)                               0.765840       0.813897
# InternVL 3.5 (4B)                               0.463335       0.544171
# InternVL 3.5 (8B)                               0.410632       0.461871
# LLaVA-v1.5 (7B)                                 0.826761       0.771359
# LLaVA-v1.6-Mistral (7B)                         0.840475       0.749105
# LLaVA-v1.6-Vicuna (7B)                          1.000000       0.737850
# Qwen3-VL (2B)                                   0.737850       1.000000
# Qwen3-VL (4B)                                   0.596482       0.611240
# Qwen3-VL (8B)                                   0.607054       0.671954
#
#                                   Qwen3-VL (4B)  Qwen3-VL (8B)
# 02f952bb_20251210_230336               0.436167       0.409653
# 0756a860_20251124_133827               0.507499       0.530005
# 14d2420f_20251208_150302               0.494478       0.491694
# 218b2db5_20251126_084136               0.518308       0.505468
# 29127478_20251202_100107               0.491655       0.509659
# 2e184452_20251205_141511_cleaned       0.482921       0.513859
# 3238ebaf_20251126_140604               0.497238       0.493736
# 3a36e078_20251205_225238               0.530505       0.546360
# 5d843d39_20251127_141921               0.487515       0.478166
# 60de6bd6_20251210_170035               0.528278       0.559495
# 6b3a1a8d_20251125_135446               0.571808       0.594201
# 73df43f3_20251204_210431               0.551300       0.523541
# 74d408e5_20251213_134035               0.514239       0.546541
# 825ff3e9_20251210_192335               0.463564       0.501322
# 9c5d09f3_20251209_121033               0.560077       0.569451
# a5909497_20251211_232822               0.484118       0.481270
# b9b2cb98_20251127_193952               0.409674       0.376413
# d1548553_20251125_202324               0.404985       0.411489
# dd0f9986_20251128_222537               0.521812       0.590101
# f616d5c7_20251203_212223               0.565971       0.577182
# InternVL 3.5 (1B)                      0.557370       0.552500
# InternVL 3.5 (2B)                      0.643002       0.675390
# InternVL 3.5 (4B)                      0.661918       0.665219
# InternVL 3.5 (8B)                      0.681568       0.653572
# LLaVA-v1.5 (7B)                        0.545568       0.571087
# LLaVA-v1.6-Mistral (7B)                0.639263       0.652993
# LLaVA-v1.6-Vicuna (7B)                 0.596482       0.607054
# Qwen3-VL (2B)                          0.611240       0.671954
# Qwen3-VL (4B)                          1.000000       0.834340
# Qwen3-VL (8B)                          0.834340       1.000000
#
# [30 rows x 30 columns]

# %%
hm.groupby(['model', 'answer_type']).size().unstack(fill_value=0).head()
# Out:
# answer_type               number  other  yes/no
# model
# InternVL3_5-1B                35    158     181
# InternVL3_5-2B                35    158     181
# InternVL3_5-4B                35    158     181
# InternVL3_5-8B                35    158     181
# InternVL3_5-8B_A1_vqa_gt      35    158     181

# %%
from utils.df import aggregate_vqa, model_name_map, calculate_mg 

df = calculate_mg(aggregate_vqa(vqa_5k), filename='vqa_5k') 
df = calculate_mg(aggregate_vqa(vqa_1k), filename='vqa_1k') 

agg = aggregate_vqa(hm).reset_index()
agg = agg[agg['model'].isin(list(pretrained_vlms))] 
agg.columns = [col[1] if isinstance(col, tuple) and len(col) > 1 and col[1] else (col[0] if isinstance(col, tuple) else col) for col in agg.columns]
ag=agg.pivot_table( 
    index=['model'], 
    values=['answer_similarity_inst_blind', 'correct_inst_blind'], 
    columns=['answer_type'], 
    aggfunc=['mean']
)

# agg.to_latex('./tables/VQA_human-model_similarity-answer_type.tex', float_format="%.1f")  
ag.to_latex('./tables/1_VQA_human-pretrained-model_similarity-answer_type.tex', float_format="%.1f")   
ag
# Out:
#                                                 mean  ...
#                         answer_similarity_inst_blind  ... correct_inst_blind
# answer_type                                   number  ...             yes/no
# model                                                 ...
# Humans                                     54.293133  ...          66.564151
# InternVL 3.5 (1B)                          67.474286  ...          68.322652
# InternVL 3.5 (2B)                          61.708571  ...          74.585083
# InternVL 3.5 (4B)                          62.408571  ...          74.400552
# InternVL 3.5 (8B)                          66.285714  ...          70.348619
# LLaVA-v1.5 (7B)                            58.371429  ...          70.349724
# LLaVA-v1.6-Mistral (7B)                    60.831429  ...          69.613260
# LLaVA-v1.6-Vicuna (7B)                     59.008571  ...          74.401657
# Qwen3-VL (2B)                              63.305714  ...          71.822099
# Qwen3-VL (4B)                              61.582857  ...          70.349171
# Qwen3-VL (8B)                              55.397143  ...          71.453591
#
# [11 rows x 6 columns]

# %%
hm_melted = hm.melt(
    id_vars=[col for col in hm.columns if col not in ['correct', 'answer_similarity']],
    value_vars=['correct', 'answer_similarity'],
    var_name='score_type',
    value_name='value'
)
hm_melted.columns
# Out:
# Index(['image_id', 'question_id', 'question_type', 'question', 'answers',
#        'multiple_choice_answer', 'answer_type', 'pid', 'output', 'model',
#        'condition', 'meta_model', '﻿question_num', 'answer', 'confidence',
#        'time_spent_seconds', 'answer_timestamp', 'participant_id',
#        'answer_original', 'answer_raw', 'answer_normalized', 'gt_answers',
#        'visual_gt', 'score_type', 'value'],
#       dtype='object')

# %%
import seaborn as sns
from scipy.stats import linregress, spearmanr

def plot_scatter(grouped, model, score_col):
    fname = f"./figures/{model.split('/')[-1]}_{score_col}.png"

    plt.figure(figsize=(6, 4))
    sns.scatterplot(
        data=grouped,
        x=f'{score_col}_human',
        y=f'{score_col}_model',
        s=50
    )
    sns.regplot(
        data=grouped,
        x=f'{score_col}_human',
        y=f'{score_col}_model',
        scatter=False,
        color='black'
    )

    plt.title(f'{model} ({score_col})')
    plt.xlabel('Human')
    plt.ylabel('Model')
    
    plt.savefig(fname, dpi=300, bbox_inches='tight')
    plt.close() 

def get_correlation_by_model( 
    mmg,
    model, 
    score_col='answer_similarity',
    grouping=['question_type'], 
):

    model_type = mmg.meta_model.unique()[0] 
    df_model = mmg[mmg['model'] == model] 

    counts = df_model.groupby(grouping).size()  
    count_stats = {
        "num_question_types": int(len(counts)),
        "min_q_per_type": int(counts.min()),
        "median_q_per_type": float(counts.median()),
        "max_q_per_type": int(counts.max()),
    }

    grouped = (
        df_model
        .groupby(grouping)
        .agg({
            f'{score_col}_human': 'mean',
            f'{score_col}_model': 'mean'
        })
        .reset_index()
    )
    x = grouped[f'{score_col}_human']
    y = grouped[f'{score_col}_model']
    
    plot_scatter(grouped, model, score_col) 
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    spearman_r, spearman_p = spearmanr(x, y)
    score_human = float(x.mean())
    score_model = float(y.mean())

    return {
        "model": model.split('/')[-1],
        "model_type": model_type,
        "eval_metric": score_col,
        "pearson_r": r_value,
        "pearson_p": p_value,
        "spearman_r": spearman_r,
        "spearman_p": spearman_p,
        "slope": slope,
        "intercept": intercept,
        "std_err": std_err,
        "model_avg": score_model,
        "human_avg": score_human,
        **count_stats,
    }, df_model

# %%
len(human_vqa), len(model_vqa)
# Out:
# (7487, 31790)

# %%
results = []
for model in mg.model.unique(): 
    results.append(get_correlation_by_model(mg, model)[0]) 
    results.append(get_correlation_by_model(mg, model, score_col='correct')[0]) 

grouped = pd.DataFrame(results)
# grouped.to_csv('./tables/vqa_model_human_correlation.csv')

# %%
# Apply to your results_df
grouped['model_clean'] = grouped['model'].map(model_name_map)  
grouped['family'] = grouped['model_clean'].str.extract(r'([^(]+)').iloc[:, 0].str.strip()
grouped['model_size'] = grouped['model_clean'].apply(extract_size)
grouped = grouped[grouped['model'].isin(pretrained_vlms)]

# %%
for score_col in grouped["eval_metric"].unique():
    subset = grouped[grouped["eval_metric"] == score_col].sort_values(by=['model_clean'])

    x = subset["pearson_r"].values
    y = subset["model_avg"].values

    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    spearman_r, _ = spearmanr(x, y)

    fig, ax = plt.subplots(figsize=(9, 6.5))

    # 1. Regression line + CI (68% for cleaner look)
    sns.regplot(
        data=subset, x="pearson_r", y="model_avg",
        scatter=False, ci=68, ax=ax,
        line_kws=dict(color="gray", linestyle="--", linewidth=1.2, alpha=0.4),
    )

    # 2. Scatter points
    for fam in subset["family"].unique():
        fam_data = subset[subset["family"] == fam]
        ax.scatter(
            fam_data["pearson_r"], fam_data["model_avg"],
            s=fam_data["model_size"] * 65,
            alpha=0.8, label=fam, edgecolors="none", zorder=3
        )

    # 3. Labeling
    texts = []
    for _, row in subset.iterrows():
        text = ax.text(
            row["pearson_r"], row["model_avg"] + ((y.max() - y.min()) * 0.04),
            row["model_clean"],
            fontsize=10, color="#333333"
        )
        texts.append(text)

    adjust_text(
        texts,
        only_move={'points': 'y', 'text': 'xy'},
        arrowprops=dict(arrowstyle='-', color='gray', alpha=0.3, lw=0.5),
        expand_text=(1.5, 2.8),
        expand_points=(1.5, 2.8),
        force_text=0.15,
        force_points=0.15,
        lim=300,
    )

    # 4. DISTINCT AXIS FORMATTING
    # Show the left and bottom spines (the "L" frame)
    for spine in ['left', 'bottom']:
        ax.spines[spine].set_visible(True)
        ax.spines[spine].set_color('black')
        ax.spines[spine].set_linewidth(1.2)
    
    # Hide the top and right spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    # Make ticks visible and pointing outward
    ax.tick_params(left=True, bottom=True, direction='out', color='black', width=1.2)

    # Tighten limits based on data
    x_margin = (x.max() - x.min()) * 0.1
    y_margin = (y.max() - y.min()) * 0.15
    ax.set_xlim(x.min() - x_margin, x.max() + x_margin)
    ax.set_ylim(y.min() - y_margin, y.max() + y_margin)
    
    ax.set_xlabel("Human–Model Alignment (Pearson $r$)", labelpad=10)
    ax.set_ylabel("Mean Model Score", labelpad=10)
    
    ax.set_title(
        f"{score_col}\n"
        f"Pearson $r$ = {r_value:.3f} ($R^2$ = {r_value**2:.3f}) | Spearman $\\rho$ = {spearman_r:.3f}",
        pad=20,
    )

    print(f"Pearson $r$ = {r_value:.3f} ($R^2$ = {r_value**2:.3f}) | Spearman $\\rho$ = {spearman_r:.3f}") 
    plt.tight_layout()
    plt.savefig(f"./figures/alignment_{score_col}.png", dpi=300, bbox_inches="tight")
    plt.show()
# Out:
# Pearson $r$ = 0.574 ($R^2$ = 0.329) | Spearman $\rho$ = 0.467
# Pearson $r$ = -0.823 ($R^2$ = 0.677) | Spearman $\rho$ = -0.721

# %%
def draw_histograms_vqa(x, y, x2, y2, save=None): 
    fig, axes = plt.subplots(2, 1, figsize=(9, 8))

    # --- Accuracy plot ---
    sns.ecdfplot(x, label="Human", ax=axes[0])
    sns.ecdfplot(y, label="Model", ax=axes[0])
    axes[0].axvline(x.mean(), color='blue', ls='--', lw=1,
                    label=f'Human μ={x.mean():.3f}')
    axes[0].axvline(y.mean(), color='orange', ls='--', lw=1,
                    label=f'Model μ={y.mean():.3f}')
    axes[0].set_xlabel("Per-question accuracy")
    axes[0].set_ylabel("ECDF")
    axes[0].set_title("Accuracy")
    axes[0].legend(frameon=False)

    # --- Embedding plot ---
    sns.ecdfplot(x2, label="Human", ax=axes[1])
    sns.ecdfplot(y2, label="Model", ax=axes[1])
    axes[1].axvline(x2.mean(), color='blue', ls='--', lw=1,
                    label=f'Human μ={x2.mean():.3f}')
    axes[1].axvline(y2.mean(), color='orange', ls='--', lw=1,
                    label=f'Model μ={y2.mean():.3f}')
    axes[1].set_xlabel("Embedding similarity (cosine)")
    axes[1].set_ylabel("ECDF")
    axes[1].set_title("Embedding")
    axes[1].legend(frameon=False)

    sns.despine()
    plt.tight_layout()

    if save is None:
        plt.show()
    else:
        plt.savefig(f"./figures/align/{save}.png", bbox_inches='tight')
    plt.close()

# %%
len((pm['correct_human'])), len(pm['correct_model']), len(pm['answer_similarity_human']), len(pm['answer_similarity_model'] )
# Out:
# (4114, 4114, 4114, 4114)

# %%
len(qids)
# Out:
# 374

# %%
cols = ['correct_model', 'answer_similarity_model', 'correct_human', 'answer_similarity_human']
for col in cols:
    pm[col] = pd.to_numeric(pm[col], errors='coerce')

pm = pm.groupby(['question_id'])[cols].mean()
# Out:
# /tmp/ipykernel_1961015/923178.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm[col] = pd.to_numeric(pm[col], errors='coerce')

# %%
draw_histograms_vqa(pm['correct_human'], pm['correct_model'], pm['answer_similarity_human'], pm['answer_similarity_model'], None)

# %%
alignments = [] 

alignments.append(acc_stat)
alignments.append(emb_stat)
pd.DataFrame(alignments)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 alignments = []
# ----> 2 acc_stat, emb_stat = draw_histograms_vqa(pm['correct_human'], pm['correct_model'], pm['answer_similarity_human'], pm['answer_similarity_model'], None)
#       4 alignments.append(acc_stat)
#       5 alignments.append(emb_stat)
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
from utils.align import calculate_alignment_suite 

def aligned_histogram(human_acc, model_acc, human_emb, model_emb, modelname='Pretrained VLMs'):  

    x,y,x2,y2= human_acc, model_acc, human_emb, model_emb 
    
    acc_stat = calculate_alignment_suite(x, y) 
    acc_stat['metric'] = 'accuracy' 
    acc_stat['model'] = modelname 

    emb_stat = calculate_alignment_suite(x2, y2) 
    emb_stat['metric'] = 'answer_similarity'
    emb_stat['model'] = modelname 
    
    draw_histograms_vqa(x, y, x2, y2, acc_stat['Pearson_r'], acc_stat['KS_Stat'], emb_stat['Pearson_r'], emb_stat['KS_Stat'], modelname) 

    print(f"Accuracy\n$r={acc_stat['Pearson_r']:.2f}$, KS={acc_stat['KS_Stat']:.2f}")
    print(f"Embedding\n$r={emb_stat['Pearson_r']:.2f}$, KS={emb_stat['KS_Stat']:.2f}") 
    return acc_stat, emb_stat
# Out:
# Accuracy
# $r=0.46$, KS=0.50
# Embedding
# $r=0.58$, KS=0.47
#    Pearson_r         r_95_CI  Spearman_rho  Kappa_Quad    TVD  JS_Dist  \
# 0      0.460  [0.446, 0.474]         0.467       0.397  0.564    0.629
# 1      0.582   [0.57, 0.594]         0.492       0.489  0.609    0.637
#
#    KS_Stat  Wasserstein  Delta_Mean             metric            model
# 0    0.499       21.628      19.806           accuracy  Pretrained VLMs
# 1    0.471       12.942      12.538  answer_similarity  Pretrained VLMs

# %%
for model in mg.model.unique():  
    df = mg[mg['model'] == model] 
    acc_stat, emb_stat = aligned_histogram(df['correct_human'], df['correct_model'], df['answer_similarity_human'], df['answer_similarity_model'], model) 

    alignments.append(acc_stat)
    alignments.append(emb_stat)
    
pd.DataFrame(alignments)
# Out:
# Accuracy
# $r=0.65$, KS=0.35
# Embedding
# $r=0.74$, KS=0.32
# Accuracy
# $r=0.63$, KS=0.37
# Embedding
# $r=0.76$, KS=0.35
# Accuracy
# $r=0.71$, KS=0.39
# Embedding
# $r=0.67$, KS=0.19
# Accuracy
# $r=0.73$, KS=0.37
# Embedding
# $r=0.70$, KS=0.29
# Accuracy
# $r=0.55$, KS=0.37
# Embedding
# $r=0.72$, KS=0.34
# Accuracy
# $r=0.64$, KS=0.39
# Embedding
# $r=0.67$, KS=0.36
# Accuracy
# $r=0.65$, KS=0.39
# Embedding
# $r=0.71$, KS=0.35
# Accuracy
# $r=0.50$, KS=0.38
# Embedding
# $r=0.66$, KS=0.37
# Accuracy
# $r=0.56$, KS=0.43
# Embedding
# $r=0.68$, KS=0.40
# Accuracy
# $r=0.73$, KS=0.42
# Embedding
# $r=0.74$, KS=0.39
# Accuracy
# $r=0.75$, KS=0.41
# Embedding
# $r=0.74$, KS=0.38
# Accuracy
# $r=0.73$, KS=0.39
# Embedding
# $r=0.73$, KS=0.31
# Accuracy
# $r=0.76$, KS=0.40
# Embedding
# $r=0.73$, KS=0.38
# Accuracy
# $r=0.52$, KS=0.45
# Embedding
# $r=0.65$, KS=0.42
# Accuracy
# $r=0.53$, KS=0.41
# Embedding
# $r=0.66$, KS=0.39
# Accuracy
# $r=0.76$, KS=0.38
# Embedding
# $r=0.73$, KS=0.34
# Accuracy
# $r=0.76$, KS=0.39
# Embedding
# $r=0.73$, KS=0.35
# Accuracy
# $r=0.66$, KS=0.39
# Embedding
# $r=0.73$, KS=0.36
# Accuracy
# $r=0.78$, KS=0.37
# Embedding
# $r=0.74$, KS=0.35
# Accuracy
# $r=0.47$, KS=0.43
# Embedding
# $r=0.59$, KS=0.42
# Accuracy
# $r=0.57$, KS=0.37
# Embedding
# $r=0.72$, KS=0.35
# Accuracy
# $r=0.76$, KS=0.37
# Embedding
# $r=0.75$, KS=0.33
# Accuracy
# $r=0.57$, KS=0.37
# Embedding
# $r=0.72$, KS=0.35
# Accuracy
# $r=0.74$, KS=0.37
# Embedding
# $r=0.75$, KS=0.34
# Accuracy
# $r=0.76$, KS=0.37
# Embedding
# $r=0.76$, KS=0.34
# Accuracy
# $r=0.78$, KS=0.38
# Embedding
# $r=0.76$, KS=0.34
# Accuracy
# $r=0.79$, KS=0.39
# Embedding
# $r=0.76$, KS=0.37
# Accuracy
# $r=0.46$, KS=0.48
# Embedding
# $r=0.56$, KS=0.46
# Accuracy
# $r=0.78$, KS=0.39
# Embedding
# $r=0.74$, KS=0.36
# Accuracy
# $r=0.58$, KS=0.43
# Embedding
# $r=0.67$, KS=0.42
# Accuracy
# $r=0.60$, KS=0.45
# Embedding
# $r=0.66$, KS=0.44
# Accuracy
# $r=0.82$, KS=0.38
# Embedding
# $r=0.80$, KS=0.37
# Accuracy
# $r=0.44$, KS=0.47
# Embedding
# $r=0.58$, KS=0.46
# Accuracy
# $r=0.50$, KS=0.35
# Embedding
# $r=0.69$, KS=0.35
# Accuracy
# $r=0.50$, KS=0.40
# Embedding
# $r=0.68$, KS=0.40
#     Pearson_r         r_95_CI  Spearman_rho  Kappa_Quad    TVD  JS_Dist  \
# 0       0.597  [0.577, 0.616]         0.602       0.561  0.564    0.612
# 1       0.694   [0.678, 0.71]         0.634       0.638  0.548    0.576
# 2       0.650  [0.587, 0.705]         0.651       0.613  0.564    0.609
# 3       0.736  [0.685, 0.779]         0.681       0.680  0.572    0.606
# 4       0.629  [0.563, 0.686]         0.651       0.590  0.567    0.614
# ..        ...             ...           ...         ...    ...      ...
# 67      0.578  [0.506, 0.642]         0.472       0.477  0.602    0.633
# 68      0.501   [0.42, 0.573]         0.513       0.476  0.564    0.609
# 69      0.686  [0.628, 0.736]         0.621       0.629  0.610    0.652
# 70      0.499  [0.418, 0.571]         0.510       0.461  0.564    0.616
# 71      0.683  [0.625, 0.734]         0.613       0.615  0.607    0.638
#
#     KS_Stat  Wasserstein  Delta_Mean             metric  \
# 0     0.378       14.404       7.326           accuracy
# 1     0.337        7.888       6.440  answer_similarity
# 2     0.353       13.553       4.911           accuracy
# 3     0.321        7.806       5.847  answer_similarity
# 4     0.374       14.693       6.337           accuracy
# ..      ...          ...         ...                ...
# 67    0.455       13.535      13.471  answer_similarity
# 68    0.348       13.508       4.733           accuracy
# 69    0.350        7.518       4.570  answer_similarity
# 70    0.401       15.666      10.170           accuracy
# 71    0.401        9.499       8.689  answer_similarity
#
#                                   model
# 0                                  None
# 1                                  None
# 2                        InternVL3_5-1B
# 3                        InternVL3_5-1B
# 4                        InternVL3_5-2B
# ..                                  ...
# 67  llava-v1.6-mistral-7b-hf_SFT_vqa_gt
# 68                      llava-1.5-7b-hf
# 69                      llava-1.5-7b-hf
# 70              llava-v1.6-vicuna-7b-hf
# 71              llava-v1.6-vicuna-7b-hf
#
# [72 rows x 11 columns]

# %%
results_df = pd.DataFrame(alignments)
rename_map = {
    "Spearman_rho": "Spearman_ρ (↑)",
    "Kappa_Quad": "Kappa_Quad (↑)",
    "TVD": "TVD (↓)",
    "JS_Dist": "JS_Dist (↓)",
    "KS_Stat": "KS_Stat (↓)",
    "Wasserstein": "Wasserstein (↓)",
    "Delta_Mean": "Δ_Mean (→0)",  # Bias is best when close to zero
    "metric": "Metric"
}

results_df = results_df.rename(columns=rename_map)
# Debug: Some columns may not be numeric, causing aggfunc='mean' to fail. Select only numeric columns.
numeric_cols = results_df.select_dtypes(include='number').columns
# Keep 'model' and 'Metric' for pivot
pivot_cols = ['model', 'Metric'] + list(numeric_cols.difference(['model', 'Metric']))
pivot_df = results_df[pivot_cols]
pivot_df = pivot_df.pivot_table(index='model', columns='Metric', aggfunc='mean')
pivot_df.to_csv('./tables/alignment.csv')
pivot_df
# Out:
#                                                   JS_Dist (↓)  \
# Metric                                               accuracy
# model
# InternVL3_5-1B                                          0.624
# InternVL3_5-2B                                          0.628
# InternVL3_5-4B                                          0.629
# InternVL3_5-8B                                          0.632
# InternVL3_5-8B_A1_vqa_gt                                0.655
# InternVL3_5-8B_A2_vqa_10_blind_inst                     0.652
# InternVL3_5-8B_A3_vqa_15_blind_inst                     0.650
# InternVL3_5-8B_A4_mmstar_15_blind_inst                  0.647
# InternVL3_5-8B_SFT_vqa_15_blind_inst                    0.650
# InternVL3_5-8B_SFT_vqa_gt                               0.659
# Pretrained VLMs                                         0.629
# Qwen3-4B                                                0.640
# Qwen3-VL-2B-Instruct                                    0.628
# Qwen3-VL-4B-Instruct                                    0.631
# Qwen3-VL-4B-Instruct_A1_vqa_gt                          0.653
# Qwen3-VL-4B-Instruct_A2_vqa_10_blind_inst               0.645
# Qwen3-VL-4B-Instruct_A3_vqa_15_blind_inst               0.647
# Qwen3-VL-4B-Instruct_A4_mmstar_15_blind_inst            0.646
# Qwen3-VL-4B-Instruct_SFT_vqa_15_blind_inst              0.645
# Qwen3-VL-4B-Instruct_SFT_vqa_gt                         0.657
# Qwen3-VL-8B-Instruct                                    0.633
# Qwen3-VL-8B-Instruct_A1_vqa_gt                          0.650
# Qwen3-VL-8B-Instruct_A2_vqa_10_blind_inst               0.647
# Qwen3-VL-8B-Instruct_A3_vqa_15_blind_inst               0.650
# Qwen3-VL-8B-Instruct_A4_mmstar_15_blind_inst            0.650
# Qwen3-VL-8B-Instruct_SFT_mmstar_15_blind_inst           0.650
# Qwen3-VL-8B-Instruct_SFT_vqa_15_blind_inst              0.648
# llava-1.5-7b-hf                                         0.626
# llava-v1.6-mistral-7b-hf                                0.631
# llava-v1.6-mistral-7b-hf_A1_vqa_gt                      0.662
# llava-v1.6-mistral-7b-hf_A2_vqa_10_blind_inst           0.644
# llava-v1.6-mistral-7b-hf_A3_vqa_15_blind_inst           0.646
# llava-v1.6-mistral-7b-hf_A4_mmstar_15_blind_inst        0.653
# llava-v1.6-mistral-7b-hf_SFT_mmstar_15_blind_inst       0.656
# llava-v1.6-mistral-7b-hf_SFT_vqa_15_blind_inst          0.638
# llava-v1.6-mistral-7b-hf_SFT_vqa_gt                     0.660
# llava-v1.6-vicuna-7b-hf                                 0.634
#
#                                                                      \
# Metric                                            answer_similarity
# model
# InternVL3_5-1B                                                0.634
# InternVL3_5-2B                                                0.628
# InternVL3_5-4B                                                0.554
# InternVL3_5-8B                                                0.609
# InternVL3_5-8B_A1_vqa_gt                                      0.678
# InternVL3_5-8B_A2_vqa_10_blind_inst                           0.669
# InternVL3_5-8B_A3_vqa_15_blind_inst                           0.663
# InternVL3_5-8B_A4_mmstar_15_blind_inst                        0.633
# InternVL3_5-8B_SFT_vqa_15_blind_inst                          0.661
# InternVL3_5-8B_SFT_vqa_gt                                     0.685
# Pretrained VLMs                                               0.637
# Qwen3-4B                                                      0.817
# Qwen3-VL-2B-Instruct                                          0.639
# Qwen3-VL-4B-Instruct                                          0.663
# Qwen3-VL-4B-Instruct_A1_vqa_gt                                0.693
# Qwen3-VL-4B-Instruct_A2_vqa_10_blind_inst                     0.652
# Qwen3-VL-4B-Instruct_A3_vqa_15_blind_inst                     0.651
# Qwen3-VL-4B-Instruct_A4_mmstar_15_blind_inst                  0.663
# Qwen3-VL-4B-Instruct_SFT_vqa_15_blind_inst                    0.649
# Qwen3-VL-4B-Instruct_SFT_vqa_gt                               0.712
# Qwen3-VL-8B-Instruct                                          0.664
# Qwen3-VL-8B-Instruct_A1_vqa_gt                                0.681
# Qwen3-VL-8B-Instruct_A2_vqa_10_blind_inst                     0.651
# Qwen3-VL-8B-Instruct_A3_vqa_15_blind_inst                     0.681
# Qwen3-VL-8B-Instruct_A4_mmstar_15_blind_inst                  0.670
# Qwen3-VL-8B-Instruct_SFT_mmstar_15_blind_inst                 0.668
# Qwen3-VL-8B-Instruct_SFT_vqa_15_blind_inst                    0.658
# llava-1.5-7b-hf                                               0.667
# llava-v1.6-mistral-7b-hf                                      0.681
# llava-v1.6-mistral-7b-hf_A1_vqa_gt                            0.704
# llava-v1.6-mistral-7b-hf_A2_vqa_10_blind_inst                 0.656
# llava-v1.6-mistral-7b-hf_A3_vqa_15_blind_inst                 0.661
# llava-v1.6-mistral-7b-hf_A4_mmstar_15_blind_inst              0.695
# llava-v1.6-mistral-7b-hf_SFT_mmstar_15_blind_inst             0.692
# llava-v1.6-mistral-7b-hf_SFT_vqa_15_blind_inst                0.635
# llava-v1.6-mistral-7b-hf_SFT_vqa_gt                           0.691
# llava-v1.6-vicuna-7b-hf                                       0.674
#
#                                                   KS_Stat (↓)  \
# Metric                                               accuracy
# model
# InternVL3_5-1B                                          0.471
# InternVL3_5-2B                                          0.491
# InternVL3_5-4B                                          0.496
# InternVL3_5-8B                                          0.512
# InternVL3_5-8B_A1_vqa_gt                                0.607
# InternVL3_5-8B_A2_vqa_10_blind_inst                     0.595
# InternVL3_5-8B_A3_vqa_15_blind_inst                     0.592
# InternVL3_5-8B_A4_mmstar_15_blind_inst                  0.580
# InternVL3_5-8B_SFT_vqa_15_blind_inst                    0.590
# InternVL3_5-8B_SFT_vqa_gt                               0.620
# Pretrained VLMs                                         0.499
# Qwen3-4B                                                0.644
# Qwen3-VL-2B-Instruct                                    0.492
# Qwen3-VL-4B-Instruct                                    0.506
# Qwen3-VL-4B-Instruct_A1_vqa_gt                          0.600
# Qwen3-VL-4B-Instruct_A2_vqa_10_blind_inst               0.564
# Qwen3-VL-4B-Instruct_A3_vqa_15_blind_inst               0.571
# Qwen3-VL-4B-Instruct_A4_mmstar_15_blind_inst            0.575
# Qwen3-VL-4B-Instruct_SFT_vqa_15_blind_inst              0.563
# Qwen3-VL-4B-Instruct_SFT_vqa_gt                         0.616
# Qwen3-VL-8B-Instruct                                    0.520
# Qwen3-VL-8B-Instruct_A1_vqa_gt                          0.590
# Qwen3-VL-8B-Instruct_A2_vqa_10_blind_inst               0.572
# Qwen3-VL-8B-Instruct_A3_vqa_15_blind_inst               0.590
# Qwen3-VL-8B-Instruct_A4_mmstar_15_blind_inst            0.588
# Qwen3-VL-8B-Instruct_SFT_mmstar_15_blind_inst           0.587
# Qwen3-VL-8B-Instruct_SFT_vqa_15_blind_inst              0.583
# llava-1.5-7b-hf                                         0.477
# llava-v1.6-mistral-7b-hf                                0.504
# llava-v1.6-mistral-7b-hf_A1_vqa_gt                      0.632
# llava-v1.6-mistral-7b-hf_A2_vqa_10_blind_inst           0.561
# llava-v1.6-mistral-7b-hf_A3_vqa_15_blind_inst           0.567
# llava-v1.6-mistral-7b-hf_A4_mmstar_15_blind_inst        0.599
# llava-v1.6-mistral-7b-hf_SFT_mmstar_15_blind_inst       0.610
# llava-v1.6-mistral-7b-hf_SFT_vqa_15_blind_inst          0.537
# llava-v1.6-mistral-7b-hf_SFT_vqa_gt                     0.622
# llava-v1.6-vicuna-7b-hf                                 0.518
#
#                                                                      \
# Metric                                            answer_similarity
# model
# InternVL3_5-1B                                                0.432
# InternVL3_5-2B                                                0.464
# InternVL3_5-4B                                                0.413
# InternVL3_5-8B                                                0.466
# InternVL3_5-8B_A1_vqa_gt                                      0.582
# InternVL3_5-8B_A2_vqa_10_blind_inst                           0.566
# InternVL3_5-8B_A3_vqa_15_blind_inst                           0.561
# InternVL3_5-8B_A4_mmstar_15_blind_inst                        0.532
# InternVL3_5-8B_SFT_vqa_15_blind_inst                          0.560
# InternVL3_5-8B_SFT_vqa_gt                                     0.594
# Pretrained VLMs                                               0.471
# Qwen3-4B                                                      0.762
# Qwen3-VL-2B-Instruct                                          0.468
# Qwen3-VL-4B-Instruct                                          0.481
# Qwen3-VL-4B-Instruct_A1_vqa_gt                                0.576
# Qwen3-VL-4B-Instruct_A2_vqa_10_blind_inst                     0.531
# Qwen3-VL-4B-Instruct_A3_vqa_15_blind_inst                     0.539
# Qwen3-VL-4B-Instruct_A4_mmstar_15_blind_inst                  0.543
# Qwen3-VL-4B-Instruct_SFT_vqa_15_blind_inst                    0.537
# Qwen3-VL-4B-Instruct_SFT_vqa_gt                               0.610
# Qwen3-VL-8B-Instruct                                          0.480
# Qwen3-VL-8B-Instruct_A1_vqa_gt                                0.572
# Qwen3-VL-8B-Instruct_A2_vqa_10_blind_inst                     0.545
# Qwen3-VL-8B-Instruct_A3_vqa_15_blind_inst                     0.572
# Qwen3-VL-8B-Instruct_A4_mmstar_15_blind_inst                  0.563
# Qwen3-VL-8B-Instruct_SFT_mmstar_15_blind_inst                 0.559
# Qwen3-VL-8B-Instruct_SFT_vqa_15_blind_inst                    0.555
# llava-1.5-7b-hf                                               0.471
# llava-v1.6-mistral-7b-hf                                      0.497
# llava-v1.6-mistral-7b-hf_A1_vqa_gt                            0.620
# llava-v1.6-mistral-7b-hf_A2_vqa_10_blind_inst                 0.539
# llava-v1.6-mistral-7b-hf_A3_vqa_15_blind_inst                 0.547
# llava-v1.6-mistral-7b-hf_A4_mmstar_15_blind_inst              0.588
# llava-v1.6-mistral-7b-hf_SFT_mmstar_15_blind_inst             0.598
# llava-v1.6-mistral-7b-hf_SFT_vqa_15_blind_inst                0.520
# llava-v1.6-mistral-7b-hf_SFT_vqa_gt                           0.612
# llava-v1.6-vicuna-7b-hf                                       0.512
#
#                                                   Kappa_Quad (↑)  \
# Metric                                                  accuracy
# model
# InternVL3_5-1B                                             0.446
# InternVL3_5-2B                                             0.434
# InternVL3_5-4B                                             0.441
# InternVL3_5-8B                                             0.453
# InternVL3_5-8B_A1_vqa_gt                                   0.313
# InternVL3_5-8B_A2_vqa_10_blind_inst                        0.399
# InternVL3_5-8B_A3_vqa_15_blind_inst                        0.414
# InternVL3_5-8B_A4_mmstar_15_blind_inst                     0.399
# InternVL3_5-8B_SFT_vqa_15_blind_inst                       0.414
# InternVL3_5-8B_SFT_vqa_gt                                  0.289
# Pretrained VLMs                                            0.397
# Qwen3-4B                                                   0.122
# Qwen3-VL-2B-Instruct                                       0.390
# Qwen3-VL-4B-Instruct                                       0.401
# Qwen3-VL-4B-Instruct_A1_vqa_gt                             0.290
# Qwen3-VL-4B-Instruct_A2_vqa_10_blind_inst                  0.426
# Qwen3-VL-4B-Instruct_A3_vqa_15_blind_inst                  0.427
# Qwen3-VL-4B-Instruct_A4_mmstar_15_blind_inst               0.365
# Qwen3-VL-4B-Instruct_SFT_vqa_15_blind_inst                 0.438
# Qwen3-VL-4B-Instruct_SFT_vqa_gt                            0.260
# Qwen3-VL-8B-Instruct                                       0.400
# Qwen3-VL-8B-Instruct_A1_vqa_gt                             0.306
# Qwen3-VL-8B-Instruct_A2_vqa_10_blind_inst                  0.404
# Qwen3-VL-8B-Instruct_A3_vqa_15_blind_inst                  0.306
# Qwen3-VL-8B-Instruct_A4_mmstar_15_blind_inst               0.381
# Qwen3-VL-8B-Instruct_SFT_mmstar_15_blind_inst              0.389
# Qwen3-VL-8B-Instruct_SFT_vqa_15_blind_inst                 0.413
# llava-1.5-7b-hf                                            0.365
# llava-v1.6-mistral-7b-hf                                   0.346
# llava-v1.6-mistral-7b-hf_A1_vqa_gt                         0.258
# llava-v1.6-mistral-7b-hf_A2_vqa_10_blind_inst              0.425
# llava-v1.6-mistral-7b-hf_A3_vqa_15_blind_inst              0.430
# llava-v1.6-mistral-7b-hf_A4_mmstar_15_blind_inst           0.326
# llava-v1.6-mistral-7b-hf_SFT_mmstar_15_blind_inst          0.332
# llava-v1.6-mistral-7b-hf_SFT_vqa_15_blind_inst             0.487
# llava-v1.6-mistral-7b-hf_SFT_vqa_gt                        0.248
# llava-v1.6-vicuna-7b-hf                                    0.348
#
#                                                                     Pearson_r  \
# Metric                                            answer_similarity  accuracy
# model
# InternVL3_5-1B                                                0.532     0.507
# InternVL3_5-2B                                                0.537     0.498
# InternVL3_5-4B                                                0.494     0.506
# InternVL3_5-8B                                                0.497     0.526
# InternVL3_5-8B_A1_vqa_gt                                      0.393     0.411
# InternVL3_5-8B_A2_vqa_10_blind_inst                           0.420     0.510
# InternVL3_5-8B_A3_vqa_15_blind_inst                           0.427     0.524
# InternVL3_5-8B_A4_mmstar_15_blind_inst                        0.436     0.499
# InternVL3_5-8B_SFT_vqa_15_blind_inst                          0.417     0.525
# InternVL3_5-8B_SFT_vqa_gt                                     0.372     0.387
# Pretrained VLMs                                               0.489     0.460
# Qwen3-4B                                                     -0.049     0.160
# Qwen3-VL-2B-Instruct                                          0.515     0.450
# Qwen3-VL-4B-Instruct                                          0.473     0.466
# Qwen3-VL-4B-Instruct_A1_vqa_gt                                0.369     0.378
# Qwen3-VL-4B-Instruct_A2_vqa_10_blind_inst                     0.420     0.526
# Qwen3-VL-4B-Instruct_A3_vqa_15_blind_inst                     0.410     0.532
# Qwen3-VL-4B-Instruct_A4_mmstar_15_blind_inst                  0.420     0.455
# Qwen3-VL-4B-Instruct_SFT_vqa_15_blind_inst                    0.427     0.541
# Qwen3-VL-4B-Instruct_SFT_vqa_gt                               0.305     0.346
# Qwen3-VL-8B-Instruct                                          0.472     0.471
# Qwen3-VL-8B-Instruct_A1_vqa_gt                                0.370     0.393
# Qwen3-VL-8B-Instruct_A2_vqa_10_blind_inst                     0.377     0.506
# Qwen3-VL-8B-Instruct_A3_vqa_15_blind_inst                     0.370     0.393
# Qwen3-VL-8B-Instruct_A4_mmstar_15_blind_inst                  0.383     0.486
# Qwen3-VL-8B-Instruct_SFT_mmstar_15_blind_inst                 0.384     0.497
# Qwen3-VL-8B-Instruct_SFT_vqa_15_blind_inst                    0.389     0.521
# llava-1.5-7b-hf                                               0.492     0.413
# llava-v1.6-mistral-7b-hf                                      0.447     0.405
# llava-v1.6-mistral-7b-hf_A1_vqa_gt                            0.282     0.351
# llava-v1.6-mistral-7b-hf_A2_vqa_10_blind_inst                 0.401     0.523
# llava-v1.6-mistral-7b-hf_A3_vqa_15_blind_inst                 0.424     0.533
# llava-v1.6-mistral-7b-hf_A4_mmstar_15_blind_inst              0.371     0.426
# llava-v1.6-mistral-7b-hf_SFT_mmstar_15_blind_inst             0.356     0.438
# llava-v1.6-mistral-7b-hf_SFT_vqa_15_blind_inst                0.478     0.581
# llava-v1.6-mistral-7b-hf_SFT_vqa_gt                           0.299     0.334
# llava-v1.6-vicuna-7b-hf                                       0.478     0.411
#
#                                                                      \
# Metric                                            answer_similarity
# model
# InternVL3_5-1B                                                0.624
# InternVL3_5-2B                                                0.634
# InternVL3_5-4B                                                0.571
# InternVL3_5-8B                                                0.587
# InternVL3_5-8B_A1_vqa_gt                                      0.523
# InternVL3_5-8B_A2_vqa_10_blind_inst                           0.559
# InternVL3_5-8B_A3_vqa_15_blind_inst                           0.566
# InternVL3_5-8B_A4_mmstar_15_blind_inst                        0.549
# InternVL3_5-8B_SFT_vqa_15_blind_inst                          0.554
# InternVL3_5-8B_SFT_vqa_gt                                     0.511
# Pretrained VLMs                                               0.582
# Qwen3-4B                                                     -0.265
# Qwen3-VL-2B-Instruct                                          0.616
# Qwen3-VL-4B-Instruct                                          0.573
# Qwen3-VL-4B-Instruct_A1_vqa_gt                                0.499
# Qwen3-VL-4B-Instruct_A2_vqa_10_blind_inst                     0.553
# Qwen3-VL-4B-Instruct_A3_vqa_15_blind_inst                     0.547
# Qwen3-VL-4B-Instruct_A4_mmstar_15_blind_inst                  0.549
# Qwen3-VL-4B-Instruct_SFT_vqa_15_blind_inst                    0.562
# Qwen3-VL-4B-Instruct_SFT_vqa_gt                               0.438
# Qwen3-VL-8B-Instruct                                          0.566
# Qwen3-VL-8B-Instruct_A1_vqa_gt                                0.501
# Qwen3-VL-8B-Instruct_A2_vqa_10_blind_inst                     0.514
# Qwen3-VL-8B-Instruct_A3_vqa_15_blind_inst                     0.501
# Qwen3-VL-8B-Instruct_A4_mmstar_15_blind_inst                  0.509
# Qwen3-VL-8B-Instruct_SFT_mmstar_15_blind_inst                 0.516
# Qwen3-VL-8B-Instruct_SFT_vqa_15_blind_inst                    0.530
# llava-1.5-7b-hf                                               0.573
# llava-v1.6-mistral-7b-hf                                      0.543
# llava-v1.6-mistral-7b-hf_A1_vqa_gt                            0.421
# llava-v1.6-mistral-7b-hf_A2_vqa_10_blind_inst                 0.534
# llava-v1.6-mistral-7b-hf_A3_vqa_15_blind_inst                 0.559
# llava-v1.6-mistral-7b-hf_A4_mmstar_15_blind_inst              0.508
# llava-v1.6-mistral-7b-hf_SFT_mmstar_15_blind_inst             0.500
# llava-v1.6-mistral-7b-hf_SFT_vqa_15_blind_inst                0.602
# llava-v1.6-mistral-7b-hf_SFT_vqa_gt                           0.440
# llava-v1.6-vicuna-7b-hf                                       0.579
#
#                                                   Spearman_ρ (↑)  \
# Metric                                                  accuracy
# model
# InternVL3_5-1B                                             0.515
# InternVL3_5-2B                                             0.516
# InternVL3_5-4B                                             0.509
# InternVL3_5-8B                                             0.519
# InternVL3_5-8B_A1_vqa_gt                                   0.425
# InternVL3_5-8B_A2_vqa_10_blind_inst                        0.519
# InternVL3_5-8B_A3_vqa_15_blind_inst                        0.529
# InternVL3_5-8B_A4_mmstar_15_blind_inst                     0.492
# InternVL3_5-8B_SFT_vqa_15_blind_inst                       0.529
# InternVL3_5-8B_SFT_vqa_gt                                  0.404
# Pretrained VLMs                                            0.467
# Qwen3-4B                                                   0.164
# Qwen3-VL-2B-Instruct                                       0.463
# Qwen3-VL-4B-Instruct                                       0.472
# Qwen3-VL-4B-Instruct_A1_vqa_gt                             0.390
# Qwen3-VL-4B-Instruct_A2_vqa_10_blind_inst                  0.521
# Qwen3-VL-4B-Instruct_A3_vqa_15_blind_inst                  0.527
# Qwen3-VL-4B-Instruct_A4_mmstar_15_blind_inst               0.460
# Qwen3-VL-4B-Instruct_SFT_vqa_15_blind_inst                 0.538
# Qwen3-VL-4B-Instruct_SFT_vqa_gt                            0.356
# Qwen3-VL-8B-Instruct                                       0.475
# Qwen3-VL-8B-Instruct_A1_vqa_gt                             0.408
# Qwen3-VL-8B-Instruct_A2_vqa_10_blind_inst                  0.496
# Qwen3-VL-8B-Instruct_A3_vqa_15_blind_inst                  0.408
# Qwen3-VL-8B-Instruct_A4_mmstar_15_blind_inst               0.480
# Qwen3-VL-8B-Instruct_SFT_mmstar_15_blind_inst              0.492
# Qwen3-VL-8B-Instruct_SFT_vqa_15_blind_inst                 0.512
# llava-1.5-7b-hf                                            0.421
# llava-v1.6-mistral-7b-hf                                   0.412
# llava-v1.6-mistral-7b-hf_A1_vqa_gt                         0.368
# llava-v1.6-mistral-7b-hf_A2_vqa_10_blind_inst              0.524
# llava-v1.6-mistral-7b-hf_A3_vqa_15_blind_inst              0.531
# llava-v1.6-mistral-7b-hf_A4_mmstar_15_blind_inst           0.434
# llava-v1.6-mistral-7b-hf_SFT_mmstar_15_blind_inst          0.452
# llava-v1.6-mistral-7b-hf_SFT_vqa_15_blind_inst             0.581
# llava-v1.6-mistral-7b-hf_SFT_vqa_gt                        0.355
# llava-v1.6-vicuna-7b-hf                                    0.421
#
#                                                                      TVD (↓)  \
# Metric                                            answer_similarity accuracy
# model
# InternVL3_5-1B                                                0.544    0.564
# InternVL3_5-2B                                                0.549    0.564
# InternVL3_5-4B                                                0.483    0.564
# InternVL3_5-8B                                                0.504    0.564
# InternVL3_5-8B_A1_vqa_gt                                      0.408    0.567
# InternVL3_5-8B_A2_vqa_10_blind_inst                           0.479    0.564
# InternVL3_5-8B_A3_vqa_15_blind_inst                           0.488    0.564
# InternVL3_5-8B_A4_mmstar_15_blind_inst                        0.457    0.564
# InternVL3_5-8B_SFT_vqa_15_blind_inst                          0.473    0.564
# InternVL3_5-8B_SFT_vqa_gt                                     0.387    0.579
# Pretrained VLMs                                               0.492    0.564
# Qwen3-4B                                                     -0.290    0.604
# Qwen3-VL-2B-Instruct                                          0.521    0.564
# Qwen3-VL-4B-Instruct                                          0.486    0.564
# Qwen3-VL-4B-Instruct_A1_vqa_gt                                0.392    0.564
# Qwen3-VL-4B-Instruct_A2_vqa_10_blind_inst                     0.479    0.564
# Qwen3-VL-4B-Instruct_A3_vqa_15_blind_inst                     0.467    0.564
# Qwen3-VL-4B-Instruct_A4_mmstar_15_blind_inst                  0.457    0.564
# Qwen3-VL-4B-Instruct_SFT_vqa_15_blind_inst                    0.480    0.564
# Qwen3-VL-4B-Instruct_SFT_vqa_gt                               0.329    0.564
# Qwen3-VL-8B-Instruct                                          0.487    0.564
# Qwen3-VL-8B-Instruct_A1_vqa_gt                                0.396    0.564
# Qwen3-VL-8B-Instruct_A2_vqa_10_blind_inst                     0.441    0.564
# Qwen3-VL-8B-Instruct_A3_vqa_15_blind_inst                     0.396    0.564
# Qwen3-VL-8B-Instruct_A4_mmstar_15_blind_inst                  0.437    0.564
# Qwen3-VL-8B-Instruct_SFT_mmstar_15_blind_inst                 0.443    0.564
# Qwen3-VL-8B-Instruct_SFT_vqa_15_blind_inst                    0.456    0.564
# llava-1.5-7b-hf                                               0.477    0.564
# llava-v1.6-mistral-7b-hf                                      0.447    0.564
# llava-v1.6-mistral-7b-hf_A1_vqa_gt                            0.303    0.584
# llava-v1.6-mistral-7b-hf_A2_vqa_10_blind_inst                 0.449    0.564
# llava-v1.6-mistral-7b-hf_A3_vqa_15_blind_inst                 0.469    0.564
# llava-v1.6-mistral-7b-hf_A4_mmstar_15_blind_inst              0.422    0.564
# llava-v1.6-mistral-7b-hf_SFT_mmstar_15_blind_inst             0.410    0.568
# llava-v1.6-mistral-7b-hf_SFT_vqa_15_blind_inst                0.525    0.564
# llava-v1.6-mistral-7b-hf_SFT_vqa_gt                           0.313    0.584
# llava-v1.6-vicuna-7b-hf                                       0.479    0.564
#
#                                                                      \
# Metric                                            answer_similarity
# model
# InternVL3_5-1B                                                0.603
# InternVL3_5-2B                                                0.591
# InternVL3_5-4B                                                0.516
# InternVL3_5-8B                                                0.582
# InternVL3_5-8B_A1_vqa_gt                                      0.662
# InternVL3_5-8B_A2_vqa_10_blind_inst                           0.658
# InternVL3_5-8B_A3_vqa_15_blind_inst                           0.654
# InternVL3_5-8B_A4_mmstar_15_blind_inst                        0.615
# InternVL3_5-8B_SFT_vqa_15_blind_inst                          0.658
# InternVL3_5-8B_SFT_vqa_gt                                     0.672
# Pretrained VLMs                                               0.609
# Qwen3-4B                                                      0.748
# Qwen3-VL-2B-Instruct                                          0.601
# Qwen3-VL-4B-Instruct                                          0.635
# Qwen3-VL-4B-Instruct_A1_vqa_gt                                0.668
# Qwen3-VL-4B-Instruct_A2_vqa_10_blind_inst                     0.647
# Qwen3-VL-4B-Instruct_A3_vqa_15_blind_inst                     0.644
# Qwen3-VL-4B-Instruct_A4_mmstar_15_blind_inst                  0.651
# Qwen3-VL-4B-Instruct_SFT_vqa_15_blind_inst                    0.644
# Qwen3-VL-4B-Instruct_SFT_vqa_gt                               0.697
# Qwen3-VL-8B-Instruct                                          0.635
# Qwen3-VL-8B-Instruct_A1_vqa_gt                                0.662
# Qwen3-VL-8B-Instruct_A2_vqa_10_blind_inst                     0.651
# Qwen3-VL-8B-Instruct_A3_vqa_15_blind_inst                     0.662
# Qwen3-VL-8B-Instruct_A4_mmstar_15_blind_inst                  0.657
# Qwen3-VL-8B-Instruct_SFT_mmstar_15_blind_inst                 0.660
# Qwen3-VL-8B-Instruct_SFT_vqa_15_blind_inst                    0.659
# llava-1.5-7b-hf                                               0.640
# llava-v1.6-mistral-7b-hf                                      0.645
# llava-v1.6-mistral-7b-hf_A1_vqa_gt                            0.699
# llava-v1.6-mistral-7b-hf_A2_vqa_10_blind_inst                 0.659
# llava-v1.6-mistral-7b-hf_A3_vqa_15_blind_inst                 0.663
# llava-v1.6-mistral-7b-hf_A4_mmstar_15_blind_inst              0.667
# llava-v1.6-mistral-7b-hf_SFT_mmstar_15_blind_inst             0.674
# llava-v1.6-mistral-7b-hf_SFT_vqa_15_blind_inst                0.631
# llava-v1.6-mistral-7b-hf_SFT_vqa_gt                           0.689
# llava-v1.6-vicuna-7b-hf                                       0.644
#
#                                                   Wasserstein (↓)  \
# Metric                                                   accuracy
# model
# InternVL3_5-1B                                             19.571
# InternVL3_5-2B                                             20.888
# InternVL3_5-4B                                             21.286
# InternVL3_5-8B                                             22.477
# InternVL3_5-8B_A1_vqa_gt                                   30.756
# InternVL3_5-8B_A2_vqa_10_blind_inst                        29.780
# InternVL3_5-8B_A3_vqa_15_blind_inst                        29.280
# InternVL3_5-8B_A4_mmstar_15_blind_inst                     28.069
# InternVL3_5-8B_SFT_vqa_15_blind_inst                       29.343
# InternVL3_5-8B_SFT_vqa_gt                                  32.039
# Pretrained VLMs                                            21.628
# Qwen3-4B                                                   27.405
# Qwen3-VL-2B-Instruct                                       21.131
# Qwen3-VL-4B-Instruct                                       22.216
# Qwen3-VL-4B-Instruct_A1_vqa_gt                             30.119
# Qwen3-VL-4B-Instruct_A2_vqa_10_blind_inst                  27.485
# Qwen3-VL-4B-Instruct_A3_vqa_15_blind_inst                  28.207
# Qwen3-VL-4B-Instruct_A4_mmstar_15_blind_inst               28.091
# Qwen3-VL-4B-Instruct_SFT_vqa_15_blind_inst                 27.547
# Qwen3-VL-4B-Instruct_SFT_vqa_gt                            31.496
# Qwen3-VL-8B-Instruct                                       22.953
# Qwen3-VL-8B-Instruct_A1_vqa_gt                             29.232
# Qwen3-VL-8B-Instruct_A2_vqa_10_blind_inst                  28.082
# Qwen3-VL-8B-Instruct_A3_vqa_15_blind_inst                  29.232
# Qwen3-VL-8B-Instruct_A4_mmstar_15_blind_inst               29.401
# Qwen3-VL-8B-Instruct_SFT_mmstar_15_blind_inst              29.374
# Qwen3-VL-8B-Instruct_SFT_vqa_15_blind_inst                 28.737
# llava-1.5-7b-hf                                            20.238
# llava-v1.6-mistral-7b-hf                                   22.115
# llava-v1.6-mistral-7b-hf_A1_vqa_gt                         33.163
# llava-v1.6-mistral-7b-hf_A2_vqa_10_blind_inst              27.240
# llava-v1.6-mistral-7b-hf_A3_vqa_15_blind_inst              27.694
# llava-v1.6-mistral-7b-hf_A4_mmstar_15_blind_inst           30.377
# llava-v1.6-mistral-7b-hf_SFT_mmstar_15_blind_inst          31.144
# llava-v1.6-mistral-7b-hf_SFT_vqa_15_blind_inst             24.866
# llava-v1.6-mistral-7b-hf_SFT_vqa_gt                        32.539
# llava-v1.6-vicuna-7b-hf                                    23.250
#
#                                                                      \
# Metric                                            answer_similarity
# model
# InternVL3_5-1B                                               11.778
# InternVL3_5-2B                                               12.790
# InternVL3_5-4B                                               11.713
# InternVL3_5-8B                                               13.169
# InternVL3_5-8B_A1_vqa_gt                                     18.059
# InternVL3_5-8B_A2_vqa_10_blind_inst                          17.741
# InternVL3_5-8B_A3_vqa_15_blind_inst                          17.658
# InternVL3_5-8B_A4_mmstar_15_blind_inst                       16.239
# InternVL3_5-8B_SFT_vqa_15_blind_inst                         17.689
# InternVL3_5-8B_SFT_vqa_gt                                    18.806
# Pretrained VLMs                                              12.942
# Qwen3-4B                                                     46.393
# Qwen3-VL-2B-Instruct                                         12.937
# Qwen3-VL-4B-Instruct                                         13.319
# Qwen3-VL-4B-Instruct_A1_vqa_gt                               17.980
# Qwen3-VL-4B-Instruct_A2_vqa_10_blind_inst                    16.884
# Qwen3-VL-4B-Instruct_A3_vqa_15_blind_inst                    17.254
# Qwen3-VL-4B-Instruct_A4_mmstar_15_blind_inst                 17.002
# Qwen3-VL-4B-Instruct_SFT_vqa_15_blind_inst                   17.113
# Qwen3-VL-4B-Instruct_SFT_vqa_gt                              19.774
# Qwen3-VL-8B-Instruct                                         13.272
# Qwen3-VL-8B-Instruct_A1_vqa_gt                               17.969
# Qwen3-VL-8B-Instruct_A2_vqa_10_blind_inst                    17.887
# Qwen3-VL-8B-Instruct_A3_vqa_15_blind_inst                    17.969
# Qwen3-VL-8B-Instruct_A4_mmstar_15_blind_inst                 17.588
# Qwen3-VL-8B-Instruct_SFT_mmstar_15_blind_inst                17.719
# Qwen3-VL-8B-Instruct_SFT_vqa_15_blind_inst                   18.085
# llava-1.5-7b-hf                                              12.073
# llava-v1.6-mistral-7b-hf                                     13.723
# llava-v1.6-mistral-7b-hf_A1_vqa_gt                           20.669
# llava-v1.6-mistral-7b-hf_A2_vqa_10_blind_inst                17.388
# llava-v1.6-mistral-7b-hf_A3_vqa_15_blind_inst                17.302
# llava-v1.6-mistral-7b-hf_A4_mmstar_15_blind_inst             18.437
# llava-v1.6-mistral-7b-hf_SFT_mmstar_15_blind_inst            19.110
# llava-v1.6-mistral-7b-hf_SFT_vqa_15_blind_inst               15.745
# llava-v1.6-mistral-7b-hf_SFT_vqa_gt                          20.353
# llava-v1.6-vicuna-7b-hf                                      14.122
#
#                                                   Δ_Mean (→0)  \
# Metric                                               accuracy
# model
# InternVL3_5-1B                                         17.032
# InternVL3_5-2B                                         18.696
# InternVL3_5-4B                                         19.468
# InternVL3_5-8B                                         20.865
# InternVL3_5-8B_A1_vqa_gt                               30.534
# InternVL3_5-8B_A2_vqa_10_blind_inst                    29.465
# InternVL3_5-8B_A3_vqa_15_blind_inst                    28.886
# InternVL3_5-8B_A4_mmstar_15_blind_inst                 27.460
# InternVL3_5-8B_SFT_vqa_15_blind_inst                   28.975
# InternVL3_5-8B_SFT_vqa_gt                              31.916
# Pretrained VLMs                                        19.806
# Qwen3-4B                                              -26.818
# Qwen3-VL-2B-Instruct                                   19.260
# Qwen3-VL-4B-Instruct                                   20.657
# Qwen3-VL-4B-Instruct_A1_vqa_gt                         29.777
# Qwen3-VL-4B-Instruct_A2_vqa_10_blind_inst              26.969
# Qwen3-VL-4B-Instruct_A3_vqa_15_blind_inst              27.772
# Qwen3-VL-4B-Instruct_A4_mmstar_15_blind_inst           27.549
# Qwen3-VL-4B-Instruct_SFT_vqa_15_blind_inst             27.059
# Qwen3-VL-4B-Instruct_SFT_vqa_gt                        31.248
# Qwen3-VL-8B-Instruct                                   21.429
# Qwen3-VL-8B-Instruct_A1_vqa_gt                         28.797
# Qwen3-VL-8B-Instruct_A2_vqa_10_blind_inst              27.594
# Qwen3-VL-8B-Instruct_A3_vqa_15_blind_inst              28.797
# Qwen3-VL-8B-Instruct_A4_mmstar_15_blind_inst           29.020
# Qwen3-VL-8B-Instruct_SFT_mmstar_15_blind_inst          29.020
# Qwen3-VL-8B-Instruct_SFT_vqa_15_blind_inst             28.262
# llava-1.5-7b-hf                                        17.805
# llava-v1.6-mistral-7b-hf                               20.419
# llava-v1.6-mistral-7b-hf_A1_vqa_gt                     33.075
# llava-v1.6-mistral-7b-hf_A2_vqa_10_blind_inst          26.658
# llava-v1.6-mistral-7b-hf_A3_vqa_15_blind_inst          27.192
# llava-v1.6-mistral-7b-hf_A4_mmstar_15_blind_inst       30.089
# llava-v1.6-mistral-7b-hf_SFT_mmstar_15_blind_inst      30.936
# llava-v1.6-mistral-7b-hf_SFT_vqa_15_blind_inst         23.984
# llava-v1.6-mistral-7b-hf_SFT_vqa_gt                    32.451
# llava-v1.6-vicuna-7b-hf                                21.816
#
#
# Metric                                            answer_similarity
# model
# InternVL3_5-1B                                               11.295
# InternVL3_5-2B                                               12.453
# InternVL3_5-4B                                               11.312
# InternVL3_5-8B                                               12.744
# InternVL3_5-8B_A1_vqa_gt                                     18.032
# InternVL3_5-8B_A2_vqa_10_blind_inst                          17.715
# InternVL3_5-8B_A3_vqa_15_blind_inst                          17.632
# InternVL3_5-8B_A4_mmstar_15_blind_inst                       15.817
# InternVL3_5-8B_SFT_vqa_15_blind_inst                         17.664
# InternVL3_5-8B_SFT_vqa_gt                                    18.778
# Pretrained VLMs                                              12.538
# Qwen3-4B                                                    -46.393
# Qwen3-VL-2B-Instruct                                         12.599
# Qwen3-VL-4B-Instruct                                         12.980
# Qwen3-VL-4B-Instruct_A1_vqa_gt                               17.929
# Qwen3-VL-4B-Instruct_A2_vqa_10_blind_inst                    16.858
# Qwen3-VL-4B-Instruct_A3_vqa_15_blind_inst                    17.228
# Qwen3-VL-4B-Instruct_A4_mmstar_15_blind_inst                 16.879
# Qwen3-VL-4B-Instruct_SFT_vqa_15_blind_inst                   17.087
# Qwen3-VL-4B-Instruct_SFT_vqa_gt                              19.721
# Qwen3-VL-8B-Instruct                                         12.767
# Qwen3-VL-8B-Instruct_A1_vqa_gt                               17.885
# Qwen3-VL-8B-Instruct_A2_vqa_10_blind_inst                    17.861
# Qwen3-VL-8B-Instruct_A3_vqa_15_blind_inst                    17.885
# Qwen3-VL-8B-Instruct_A4_mmstar_15_blind_inst                 17.445
# Qwen3-VL-8B-Instruct_SFT_mmstar_15_blind_inst                17.599
# Qwen3-VL-8B-Instruct_SFT_vqa_15_blind_inst                   18.058
# llava-1.5-7b-hf                                              11.102
# llava-v1.6-mistral-7b-hf                                     13.424
# llava-v1.6-mistral-7b-hf_A1_vqa_gt                           20.644
# llava-v1.6-mistral-7b-hf_A2_vqa_10_blind_inst                17.357
# llava-v1.6-mistral-7b-hf_A3_vqa_15_blind_inst                17.258
# llava-v1.6-mistral-7b-hf_A4_mmstar_15_blind_inst             18.408
# llava-v1.6-mistral-7b-hf_SFT_mmstar_15_blind_inst            19.081
# llava-v1.6-mistral-7b-hf_SFT_vqa_15_blind_inst               15.687
# llava-v1.6-mistral-7b-hf_SFT_vqa_gt                          20.328
# llava-v1.6-vicuna-7b-hf                                      13.817
