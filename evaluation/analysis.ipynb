# %% [markdown]
# # Human-Model Alignment Analysis for VLM Evaluation
#
# This notebook contains the complete analysis pipeline for the paper.
#
# ## Table of Contents
# 1. [Data Processing](#1-data-processing)
# 2. [Model-Human Correlation Analysis](#2-model-human-correlation)
# 3. [Multimodal Gains Analysis](#3-multimodal-gains)
# 4. [Instruction Effects](#4-instruction-effects)
# 5. [Pretrained vs Finetuned Comparison](#5-pretrained-vs-finetuned)
# 6. [Paper Figures and Tables](#6-paper-outputs)
#
# ---

# %%
# Imports
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 11

print("✓ Imports complete")
# Out:
# ✓ Imports complete

# %% [markdown]
# ## Configuration
#
# Set paths to data directories.

# %%
# Paths
SESSION = "s1"
root_dir = "/home/work/yuna/HPA/" 
HUMAN_DATA_DIR=f"{root_dir}/data/humans/all_results_20251206_154732"
HUMAN_PROCESSED_DIR = "/home/work/yuna/HPA/evaluation/scored/humans" 
MODEL_DIR = os.path.join(root_dir, "evaluation/data/scored")
FINETUNED_DIR = os.path.join(root_dir, "evaluation/data/finetuned_scored")
OUTPUT_DIR = os.path.join(root_dir, "evaluation/paper_results")
FIGURES_DIR = os.path.join(OUTPUT_DIR, "figures")

# Create output directories
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(FIGURES_DIR, exist_ok=True)

print(f"Output directory: {OUTPUT_DIR}")
print(f"Figures directory: {FIGURES_DIR}")
# Out:
# Output directory: /home/work/yuna/HPA/evaluation/paper_results
# Figures directory: /home/work/yuna/HPA/evaluation/paper_results/figures

# %% [markdown]
# ---
#
# ## 1. Data Processing
#
# Process raw human responses to compute per-question metrics.

# %%
# Run processing script
# !python score_humans.py \
    --human_data_dir {HUMAN_DATA_DIR} \
    --session {SESSION} \
    --output_dir {HUMAN_PROCESSED_DIR} \
    --with_similarity
# Out:
# ============================================================
# 📊 Processing Raw Human Responses
#    Session: s1
#    Data dir: /home/work/yuna/HPA//data/humans/all_results_20251206_154732
# ============================================================
#
# 📚 Loading annotations...
#
# 🔧 Loading sentence transformer...
#    ✓ Encoder loaded
#
# ============================================================
# Processing VQA (text) responses...
# ============================================================
# ============================================================
# 📋 ANSWER PREPROCESSING PIPELINE
# ============================================================
#
# [1/5] Loading data...
# ✓ Loaded 641 questions from /home/work/yuna/HPA/dataset/questions/s1.csv
# /home/work/yuna/HPA//data/humans/all_results_20251206_154732/1ed1a464_20251204_110002/answers.csv is incomplete, skip
# /home/work/yuna/HPA//data/humans/all_results_20251206_154732/99f271ae_20251203_111155/answers.csv is incomplete, skip
# ✓ Loaded 9622 responses from 15 files
#
# [2/5] Translating Korean answers...
# ✓ Loaded 1381 cached translations from /home/work/yuna/HPA/preprocessing/translation_cache.json
#
# 🌐 Translation Status:
#    Total responses: 9622
#    Korean answers: 4838
#    Already cached: 4838
#    Need translation: 0
#
# [3/5] Normalizing answers...
#    ✓ /home/work/yuna/HPA/evaluation/human_analysis/cleaned_n15_choice.json
#    ✓ /home/work/yuna/HPA/evaluation/human_analysis/cleaned_n15_text.json
#
# [5/5] Saving outputs...
#    ✓ /home/work/yuna/HPA/evaluation/human_analysis/preprocessing_stats.json
#
# ============================================================
# 📊 PREPROCESSING SUMMARY
# ============================================================
#    total_responses: 9622
#    total_questions: 641
#    total_participants: 15
#    korean_translated: 4838
#    unique_answers: 1069
# ============================================================
#    Loading VQA annotations from /home/work/yuna/VLMEval/data/v2_mscoco_val2014_annotations.json...
#    ✓ Loaded 214354 VQA annotations
#    Found 374 VQA questions
# Processing VQA: 100%|█████████████████████████| 374/374 [02:32<00:00,  2.45it/s]
#
#    ✓ Saved: /home/work/yuna/HPA/evaluation/human_analysis/human_vqa_per_question.csv
#    ✓ Saved: /home/work/yuna/HPA/evaluation/human_analysis/human_vqa_stats.json
#
# ============================================================
# Processing MC (choice) responses...
# ============================================================
#    Found 374 VQA questions
# original qid found 664
# original qid found 6
# original qid found 662
# original qid found 773
# original qid found 556
# original qid found 768
# original qid found 802
# original qid found 598
# original qid found 70
# original qid found 97
# original qid found 462
# original qid found 428
# original qid found 13
# original qid found 414
# original qid found 550
# original qid found 816
# original qid found 788
# original qid found 317
# original qid found 160
# original qid found 357
# original qid found 423
# original qid found 250
# original qid found 129
# original qid found 349
# original qid found 392
# original qid found 384
# original qid found 502
# original qid found 552
# original qid found 802
# original qid found 654
# original qid found 544
# original qid found 529
# original qid found 89
# original qid found 140
# original qid found 10
# original qid found 433
# original qid found 587
# original qid found 227
# original qid found 430
# original qid found 74
# original qid found 281
# original qid found 799
# original qid found 263
# original qid found 264
# original qid found 29
# original qid found 132
# original qid found 436
# original qid found 802
# original qid found 194
# original qid found 269
# original qid found 254
# original qid found 419
# original qid found 228
# original qid found 229
# original qid found 412
# original qid found 159
# original qid found 162
# original qid found 391
# original qid found 394
# original qid found 266
# original qid found 420
# original qid found 144
# original qid found 145
# original qid found 659
# original qid found 660
# original qid found 31
# original qid found 99
# original qid found 61
# original qid found 37
# original qid found 249
# original qid found 353
# original qid found 329
# original qid found 347
# original qid found 247
# original qid found 654
# original qid found 88
# original qid found 393
# original qid found 100
# original qid found 113
# original qid found 147
# original qid found 397
# original qid found 360
# original qid found 315
# original qid found 307
# original qid found 260
# original qid found 431
# original qid found 212
# original qid found 219
# original qid found 386
# original qid found 330
# original qid found 319
# original qid found 447
# original qid found 442
# original qid found 383
# original qid found 375
# original qid found 292
# original qid found 401
# original qid found 295
# original qid found 493
# original qid found 919
# original qid found 609
# original qid found 569
# original qid found 168
# original qid found 669
# original qid found 395
# original qid found 882
# original qid found 221
# original qid found 54
# original qid found 551
# original qid found 504
# original qid found 913
# original qid found 654
# original qid found 802
# original qid found 502
# original qid found 370
# original qid found 425
# original qid found 544
# original qid found 663
# original qid found 181
# original qid found 510
# original qid found 510
# original qid found 278
# original qid found 24
# original qid found 245
# original qid found 654
# original qid found 231
# original qid found 502
# original qid found 215
# original qid found 441
# original qid found 494
# original qid found 46
# original qid found 287
# original qid found 239
# original qid found 3
# original qid found 93
# original qid found 336
# original qid found 766
# original qid found 379
# original qid found 279
# original qid found 165
# original qid found 86
# original qid found 168
# original qid found 544
# original qid found 802
# original qid found 38
# original qid found 19
# original qid found 123
# original qid found 56
# original qid found 654
# original qid found 94
# original qid found 373
# original qid found 33
# original qid found 93
# original qid found 378
# original qid found 410
# original qid found 55
# original qid found 368
# original qid found 333
# original qid found 306
# original qid found 359
# original qid found 181
# original qid found 405
# original qid found 48
# original qid found 654
# original qid found 771
# original qid found 885
# original qid found 490
# original qid found 515
# original qid found 39
# original qid found 140
# original qid found 226
# original qid found 498
# original qid found 341
# original qid found 721
# original qid found 598
# original qid found 813
# original qid found 588
# original qid found 151
# original qid found 214
# original qid found 119
# original qid found 472
# original qid found 194
# original qid found 95
# original qid found 898
# original qid found 813
# original qid found 296
# original qid found 168
# original qid found 502
# original qid found 334
# original qid found 499
# original qid found 168
# original qid found 724
# original qid found 305
# original qid found 75
# original qid found 147
# original qid found 11
# original qid found 277
# original qid found 81
# original qid found 502
# original qid found 34
# original qid found 415
# original qid found 810
# original qid found 553
# original qid found 802
# original qid found 585
# original qid found 274
# original qid found 304
# original qid found 348
# original qid found 567
# original qid found 147
# original qid found 147
# original qid found 21
# original qid found 308
# original qid found 140
# original qid found 567
# original qid found 19
# original qid found 910
# original qid found 560
# original qid found 27
# original qid found 167
# original qid found 532
# original qid found 19
# original qid found 526
# original qid found 140
# original qid found 426
# original qid found 109
# original qid found 793
# original qid found 241
# original qid found 197
# original qid found 84
# original qid found 335
# original qid found 265
# original qid found 441
# original qid found 477
# original qid found 556
# original qid found 128
# original qid found 526
# original qid found 301
# original qid found 325
# original qid found 413
# original qid found 611
# original qid found 654
# original qid found 445
# original qid found 784
# original qid found 421
# original qid found 309
# original qid found 530
# original qid found 535
# original qid found 352
# original qid found 614
# original qid found 70
# original qid found 211
# original qid found 481
# original qid found 218
# original qid found 654
# original qid found 50
# original qid found 131
# original qid found 153
# original qid found 447
# original qid found 385
# original qid found 376
# original qid found 898
# original qid found 606
# original qid found 677
# original qid found 502
# original qid found 342
# original qid found 502
# original qid found 802
# original qid found 802
# original qid found 654
# original qid found 654
# original qid found 802
# original qid found 502
# original qid found 544
# original qid found 510
# original qid found 654
# original qid found 502
# original qid found 168
# original qid found 544
# original qid found 802
# original qid found 654
# original qid found 93
# original qid found 181
# original qid found 654
# original qid found 140
# original qid found 598
# original qid found 194
# original qid found 813
# original qid found 168
# original qid found 502
# original qid found 168
# original qid found 147
# original qid found 502
# original qid found 802
# original qid found 147
# original qid found 147
# original qid found 140
# original qid found 567
# original qid found 19
# original qid found 19
# original qid found 140
# original qid found 441
# original qid found 556
# original qid found 526
# original qid found 654
# original qid found 70
# original qid found 654
# original qid found 447
# original qid found 898
# original qid found 502
# original qid found 502
# original qid found 802
# original qid found 802
# original qid found 654
# original qid found 654
# original qid found 802
# original qid found 502
# original qid found 544
# original qid found 510
# original qid found 654
# original qid found 502
# original qid found 168
# original qid found 544
# original qid found 802
# original qid found 654
# original qid found 93
# original qid found 181
# original qid found 654
# original qid found 140
# original qid found 598
# original qid found 194
# original qid found 813
# original qid found 168
# original qid found 502
# original qid found 168
# original qid found 147
# original qid found 502
# original qid found 802
# original qid found 147
# original qid found 147
# original qid found 140
# original qid found 567
# original qid found 19
# original qid found 19
# original qid found 140
# original qid found 441
# original qid found 556
# original qid found 526
# original qid found 654
# original qid found 70
# original qid found 654
# original qid found 447
# original qid found 898
# original qid found 502
# original qid found 502
# original qid found 802
# original qid found 802
# original qid found 654
# original qid found 654
# original qid found 802
# original qid found 502
# original qid found 544
# original qid found 510
# original qid found 654
# original qid found 502
# original qid found 168
# original qid found 544
# original qid found 802
# original qid found 654
# original qid found 93
# original qid found 181
# original qid found 654
# original qid found 140
# original qid found 598
# original qid found 194
# original qid found 813
# original qid found 168
# original qid found 502
# original qid found 168
# original qid found 147
# original qid found 502
# original qid found 802
# original qid found 147
# original qid found 147
# original qid found 140
# original qid found 567
# original qid found 19
# original qid found 19
# original qid found 140
# original qid found 441
# original qid found 556
# original qid found 526
# original qid found 654
# original qid found 70
# original qid found 654
# original qid found 447
# original qid found 898
# original qid found 502
# original qid found 502
# original qid found 802
# original qid found 802
# original qid found 654
# original qid found 654
# original qid found 802
# original qid found 502
# original qid found 544
# original qid found 510
# original qid found 654
# original qid found 502
# original qid found 168
# original qid found 544
# original qid found 802
# original qid found 654
# original qid found 93
# original qid found 181
# original qid found 654
# original qid found 140
# original qid found 598
# original qid found 194
# original qid found 813
# original qid found 168
# original qid found 502
# original qid found 168
# original qid found 147
# original qid found 502
# original qid found 802
# original qid found 147
# original qid found 147
# original qid found 140
# original qid found 567
# original qid found 19
# original qid found 19
# original qid found 140
# original qid found 441
# original qid found 556
# original qid found 526
# original qid found 654
# original qid found 70
# original qid found 654
# original qid found 447
# original qid found 898
# original qid found 502
# original qid found 502
# original qid found 802
# original qid found 802
# original qid found 654
# original qid found 654
# original qid found 802
# original qid found 502
# original qid found 544
# original qid found 510
# original qid found 654
# original qid found 502
# original qid found 168
# original qid found 544
# original qid found 802
# original qid found 654
# original qid found 93
# original qid found 181
# original qid found 654
# original qid found 140
# original qid found 598
# original qid found 194
# original qid found 813
# original qid found 168
# original qid found 502
# original qid found 168
# original qid found 147
# original qid found 502
# original qid found 802
# original qid found 147
# original qid found 147
# original qid found 140
# original qid found 567
# original qid found 19
# original qid found 19
# original qid found 140
# original qid found 441
# original qid found 556
# original qid found 526
# original qid found 654
# original qid found 70
# original qid found 654
# original qid found 447
# original qid found 898
# original qid found 502
# original qid found 502
# original qid found 802
# original qid found 802
# original qid found 654
# original qid found 654
# original qid found 802
# original qid found 502
# original qid found 544
# original qid found 510
# original qid found 654
# original qid found 502
# original qid found 168
# original qid found 544
# original qid found 802
# original qid found 654
# original qid found 93
# original qid found 181
# original qid found 654
# original qid found 140
# original qid found 598
# original qid found 194
# original qid found 813
# original qid found 168
# original qid found 502
# original qid found 168
# original qid found 147
# original qid found 502
# original qid found 802
# original qid found 147
# original qid found 147
# original qid found 140
# original qid found 567
# original qid found 19
# original qid found 19
# original qid found 140
# original qid found 441
# original qid found 556
# original qid found 526
# original qid found 654
# original qid found 70
# original qid found 654
# original qid found 447
# original qid found 898
# original qid found 502
# original qid found 502
# original qid found 802
# original qid found 802
# original qid found 654
# original qid found 654
# original qid found 802
# original qid found 502
# original qid found 544
# original qid found 510
# original qid found 654
# original qid found 502
# original qid found 168
# original qid found 544
# original qid found 802
# original qid found 654
# original qid found 93
# original qid found 181
# original qid found 654
# original qid found 654
# original qid found 140
# original qid found 598
# original qid found 194
# original qid found 813
# original qid found 168
# original qid found 502
# original qid found 168
# original qid found 168
# original qid found 147
# original qid found 502
# original qid found 802
# original qid found 147
# original qid found 147
# original qid found 140
# original qid found 567
# original qid found 19
# original qid found 19
# original qid found 140
# original qid found 441
# original qid found 556
# original qid found 526
# original qid found 654
# original qid found 70
# original qid found 654
# original qid found 447
# original qid found 898
# original qid found 502
# original qid found 502
# original qid found 802
# original qid found 802
# original qid found 654
# original qid found 654
# original qid found 802
# original qid found 502
# original qid found 544
# original qid found 510
# original qid found 654
# original qid found 502
# original qid found 168
# original qid found 544
# original qid found 802
# original qid found 654
# original qid found 93
# original qid found 181
# original qid found 654
# original qid found 140
# original qid found 598
# original qid found 194
# original qid found 813
# original qid found 168
# original qid found 502
# original qid found 168
# original qid found 147
# original qid found 502
# original qid found 802
# original qid found 147
# original qid found 147
# original qid found 140
# original qid found 567
# original qid found 19
# original qid found 19
# original qid found 140
# original qid found 441
# original qid found 556
# original qid found 526
# original qid found 654
# original qid found 70
# original qid found 654
# original qid found 447
# original qid found 898
# original qid found 502
# original qid found 502
# original qid found 802
# original qid found 802
# original qid found 654
# original qid found 654
# original qid found 802
# original qid found 502
# original qid found 544
# original qid found 510
# original qid found 654
# original qid found 502
# original qid found 168
# original qid found 544
# original qid found 802
# original qid found 654
# original qid found 93
# original qid found 181
# original qid found 654
# original qid found 140
# original qid found 598
# original qid found 194
# original qid found 813
# original qid found 168
# original qid found 502
# original qid found 168
# original qid found 147
# original qid found 502
# original qid found 802
# original qid found 147
# original qid found 147
# original qid found 140
# original qid found 567
# original qid found 19
# original qid found 19
# original qid found 140
# original qid found 441
# original qid found 556
# original qid found 526
# original qid found 654
# original qid found 70
# original qid found 654
# original qid found 447
# original qid found 898
# original qid found 502
# original qid found 502
# original qid found 802
# original qid found 802
# original qid found 654
# original qid found 654
# original qid found 802
# original qid found 502
# original qid found 544
# original qid found 510
# original qid found 654
# original qid found 502
# original qid found 168
# original qid found 544
# original qid found 802
# original qid found 654
# original qid found 93
# original qid found 181
# original qid found 654
# original qid found 140
# original qid found 598
# original qid found 194
# original qid found 813
# original qid found 168
# original qid found 502
# original qid found 168
# original qid found 147
# original qid found 502
# original qid found 802
# original qid found 147
# original qid found 147
# original qid found 140
# original qid found 567
# original qid found 19
# original qid found 19
# original qid found 140
# original qid found 441
# original qid found 556
# original qid found 526
# original qid found 654
# original qid found 70
# original qid found 654
# original qid found 447
# original qid found 898
# original qid found 502
# original qid found 502
# original qid found 802
# original qid found 802
# original qid found 654
# original qid found 654
# original qid found 802
# original qid found 502
# original qid found 544
# original qid found 510
# original qid found 654
# original qid found 502
# original qid found 168
# original qid found 544
# original qid found 802
# original qid found 654
# original qid found 93
# original qid found 181
# original qid found 654
# original qid found 140
# original qid found 598
# original qid found 194
# original qid found 813
# original qid found 168
# original qid found 502
# original qid found 168
# original qid found 147
# original qid found 502
# original qid found 802
# original qid found 147
# original qid found 147
# original qid found 140
# original qid found 567
# original qid found 19
# original qid found 19
# original qid found 140
# original qid found 441
# original qid found 556
# original qid found 526
# original qid found 654
# original qid found 70
# original qid found 654
# original qid found 447
# original qid found 898
# original qid found 502
# original qid found 502
# original qid found 802
# original qid found 802
# original qid found 654
# original qid found 654
# original qid found 802
# original qid found 502
# original qid found 544
# original qid found 510
# original qid found 654
# original qid found 502
# original qid found 168
# original qid found 544
# original qid found 802
# original qid found 654
# original qid found 93
# original qid found 181
# original qid found 654
# original qid found 140
# original qid found 598
# original qid found 194
# original qid found 813
# original qid found 168
# original qid found 502
# original qid found 168
# original qid found 147
# original qid found 502
# original qid found 802
# original qid found 147
# original qid found 147
# original qid found 140
# original qid found 567
# original qid found 19
# original qid found 19
# original qid found 140
# original qid found 441
# original qid found 556
# original qid found 526
# original qid found 654
# original qid found 70
# original qid found 654
# original qid found 447
# original qid found 898
# original qid found 502
# original qid found 502
# original qid found 802
# original qid found 802
# original qid found 654
# original qid found 654
# original qid found 802
# original qid found 502
# original qid found 544
# original qid found 510
# original qid found 654
# original qid found 502
# original qid found 168
# original qid found 544
# original qid found 802
# original qid found 654
# original qid found 93
# original qid found 181
# original qid found 654
# original qid found 140
# original qid found 598
# original qid found 194
# original qid found 813
# original qid found 168
# original qid found 502
# original qid found 168
# original qid found 147
# original qid found 502
# original qid found 802
# original qid found 147
# original qid found 147
# original qid found 140
# original qid found 567
# original qid found 19
# original qid found 19
# original qid found 140
# original qid found 441
# original qid found 556
# original qid found 526
# original qid found 654
# original qid found 70
# original qid found 654
# original qid found 447
# original qid found 898
# original qid found 502
# original qid found 502
# original qid found 802
# original qid found 802
# original qid found 654
# original qid found 654
# original qid found 802
# original qid found 502
# original qid found 544
# original qid found 510
# original qid found 654
# original qid found 502
# original qid found 168
# original qid found 544
# original qid found 802
# original qid found 654
# original qid found 93
# original qid found 181
# original qid found 654
# original qid found 140
# original qid found 598
# original qid found 194
# original qid found 813
# original qid found 168
# original qid found 502
# original qid found 168
# original qid found 147
# original qid found 502
# original qid found 802
# original qid found 147
# original qid found 147
# original qid found 140
# original qid found 567
# original qid found 19
# original qid found 19
# original qid found 140
# original qid found 441
# original qid found 556
# original qid found 526
# original qid found 654
# original qid found 70
# original qid found 654
# original qid found 447
# original qid found 898
# original qid found 502
# original qid found 502
#    Found 223 MC questions
# Processing MC: 100%|████████████████████████| 223/223 [00:00<00:00, 9254.00it/s]
#
#    ✓ Saved: /home/work/yuna/HPA/evaluation/human_analysis/human_mc_per_question.csv
#    ✓ Saved: /home/work/yuna/HPA/evaluation/human_analysis/human_mc_stats.json
#
# ============================================================
# 📈 Summary
# ============================================================
# VQA Questions: 374
#   Mean Accuracy: 0.3863
#   Mean Confidence: 0.6629
#   Correlation (Conf-Acc): 0.0728
#   Mean GT Similarity: 0.6328
#   Correlation (GT Sim-Acc): 0.7787
#   Mean Visual Similarity: 0.6375
#   Correlation (Visual Sim-Acc): 0.7955
#
# MC Questions: 223
#   Mean Accuracy: 0.2739
#   Mean Confidence: 0.5910
#   Correlation (Conf-Acc): 0.0929
#
# ✅ Processing complete! Results saved to: /home/work/yuna/HPA/evaluation/human_analysis

# %%
# Load processed human data
def load_human_data(answer_type='vqa'):
    path = f"/home/work/yuna/HPA/evaluation/scored/humans/human_{answer_type}_per_question.csv"
    print(path)
    df = pd.read_csv(path)
    return df 

human_vqa_df = load_human_data('vqa').dropna(axis=1)
human_mc_df = load_human_data('mc').dropna(axis=1)

print(f"VQA Questions: {len(human_vqa_df)}")
print(f"MC Questions: {len(human_mc_df)}")
# print("\nVQA Columns:", human_vqa_df.columns.tolist())
# print("\nMC Columns:", human_mc_df.columns.tolist())
# Out:
# /home/work/yuna/HPA/evaluation/scored/humans/human_vqa_per_question.csv
# /home/work/yuna/HPA/evaluation/scored/humans/human_mc_per_question.csv
# VQA Questions: 374
# MC Questions: 267

# %% [markdown]
# ### Human Performance Summary

# %%
# Load statistics
with open(os.path.join(HUMAN_PROCESSED_DIR, 'human_vqa_stats.json')) as f:
    vqa_stats = json.load(f)

with open(os.path.join(HUMAN_PROCESSED_DIR, 'human_mc_stats.json')) as f:
    mc_stats = json.load(f)

print("=" * 60)
print("HUMAN PERFORMANCE BASELINE")
print("=" * 60)
print("\nVQA (Text):")
print(f"  Questions: {vqa_stats['num_questions']}")
print(f"  Mean Accuracy: {vqa_stats['mean_accuracy']:.4f}")
print(f"  Mean Confidence: {vqa_stats['mean_confidence']:.4f}")
print(f"  Correlation (Confidence-Accuracy): {vqa_stats['correlation_conf_acc']:.4f}")
if 'mean_gt_similarity' in vqa_stats:
    print(f"  Mean GT Similarity: {vqa_stats['mean_gt_similarity']:.4f}")
    print(f"  Correlation (GT Sim-Accuracy): {vqa_stats['correlation_gt_sim_acc']:.4f}")
if 'mean_visual_similarity' in vqa_stats:
    print(f"  Mean Visual Similarity: {vqa_stats['mean_visual_similarity']:.4f}")
    print(f"  Correlation (Visual Sim-Accuracy): {vqa_stats['correlation_visual_sim_acc']:.4f}")

print("\nMultiple Choice:")
print(f"  Questions: {mc_stats['num_questions']}")
print(f"  Mean Accuracy: {mc_stats['mean_accuracy']:.4f}")
print(f"  Mean Confidence: {mc_stats['mean_confidence']:.4f}")
print(f"  Correlation (Confidence-Accuracy): {mc_stats['correlation_conf_acc']:.4f}")
# Out:
# ============================================================
# HUMAN PERFORMANCE BASELINE
# ============================================================
#
# VQA (Text):
#   Questions: 374
#   Mean Accuracy: 0.3863
#   Mean Confidence: 0.6629
#   Correlation (Confidence-Accuracy): 0.0728
#
# Multiple Choice:
#   Questions: 267
#   Mean Accuracy: 0.2677
#   Mean Confidence: 0.5872
#   Correlation (Confidence-Accuracy): 0.0935

# %% [markdown]
# ---
#
# ## 2. Model-Human Correlation Analysis
#
# **Research Question**: How well do model predictions correlate with human responses?
#
# We analyze:
# - **GT Similarity**: Correlation between model accuracy and human similarity to ground truth annotations
# - **Visual Similarity**: Correlation between model accuracy and human similarity to visual ground truth (humans who saw images)
#
# **Interpretation**:
# - GT similarity measures objective alignment with annotators
# - Visual similarity measures alignment with "oracle" humans who had full image context

# %%
# !python /home/work/yuna/HPA/evaluation/score_results.py --input_dir finetuned --with_similarity 
# !python /home/work/yuna/HPA/evaluation/score_results.py --input_dir pretrained --with_similarity
# Out:
# Found 159 files to score
# 📊 Scoring: /home/work/yuna/HPA/evaluation/results/finetuned/InternVL3_5-8B/InternVL3_5-8B_SFT_mmstar_15_blind_instfold_0/mmstar.jsonl
# > /home/work/yuna/HPA/evaluation/score_results.py(290)score_file()
# -> if dataset_type == 'multi-choice':
# (Pdb)

# %%
fr = pd.read_csv("/home/work/yuna/HPA/evaluation/scored/finetuned/summary.csv")
fr
# Out:
#                           file  \
# 0                 mmstar.jsonl
# 1      mmstar_inst_blind.jsonl
# 2               spubench.jsonl
# 3    spubench_inst_blind.jsonl
# 4                 vqa_1k.jsonl
# ..                         ...
# 148               mmstar.jsonl
# 149    mmstar_inst_blind.jsonl
# 150             spubench.jsonl
# 151  spubench_inst_blind.jsonl
# 152               vqa_5k.jsonl
#
#                                                  model   dataset    condition  \
# 0    OpenGVLab/InternVL3_5-8B/InternVL3_5-8B_A1_vqa...    mmstar          NaN
# 1    OpenGVLab/InternVL3_5-8B/InternVL3_5-8B_A1_vqa...    mmstar  _inst_blind
# 2    OpenGVLab/InternVL3_5-8B/InternVL3_5-8B_A1_vqa...  spubench          NaN
# 3    OpenGVLab/InternVL3_5-8B/InternVL3_5-8B_A1_vqa...  spubench  _inst_blind
# 4    OpenGVLab/InternVL3_5-8B/InternVL3_5-8B_A1_vqa...    vqa_1k          NaN
# ..                                                 ...       ...          ...
# 148  llava-hf/llava-v1.6-mistral-7b-hf/llava-v1.6-m...    mmstar          NaN
# 149  llava-hf/llava-v1.6-mistral-7b-hf/llava-v1.6-m...    mmstar  _inst_blind
# 150  llava-hf/llava-v1.6-mistral-7b-hf/llava-v1.6-m...  spubench          NaN
# 151  llava-hf/llava-v1.6-mistral-7b-hf/llava-v1.6-m...  spubench  _inst_blind
# 152  llava-hf/llava-v1.6-mistral-7b-hf/llava-v1.6-m...    vqa_5k          NaN
#
#      accuracy  correct  total  \
# 0    0.674667     1012   1500
# 1    0.304667      457   1500
# 2    0.000000        0   2400
# 3    0.000000        0   2400
# 4    0.762000      762   1000
# ..        ...      ...    ...
# 148  0.368667      553   1500
# 149  0.248000      372   1500
# 150  0.000000        0   2400
# 151  0.000000        0   2400
# 152  0.738165     3290   4457
#
#                                            by_category
# 0    {'coarse perception': {'accuracy': 0.74, 'corr...
# 1    {'coarse perception': {'accuracy': 0.28, 'corr...
# 2    {'Unknown': {'accuracy': 0.0, 'correct': 0, 't...
# 3    {'Unknown': {'accuracy': 0.0, 'correct': 0, 't...
# 4    {'what is the woman': {'accuracy': 0.25, 'corr...
# ..                                                 ...
# 148  {'coarse perception': {'accuracy': 0.612, 'cor...
# 149  {'coarse perception': {'accuracy': 0.228, 'cor...
# 150  {'Unknown': {'accuracy': 0.0, 'correct': 0, 't...
# 151  {'Unknown': {'accuracy': 0.0, 'correct': 0, 't...
# 152  {'what are': {'accuracy': 0.6285714285714286, ...
#
# [153 rows x 8 columns]

# %%
# Helper function to load model results
def load_model_results(file_path):
    data = []
    with open(file_path, 'r') as f:
        for line in f:
            if line.strip():
                data.append(json.loads(line))
    return pd.DataFrame(data)

# Example: Load one model for correlation analysis
model_path = os.path.join(MODEL_DIR, "InternVL3_5-2B_vqa_1k_inst_blind.jsonl")

if os.path.exists(model_path):
    model_df = load_model_results(model_path)
    print(f"Loaded model: {len(model_df)} responses")
    print("Columns:", model_df.columns.tolist())
else:
    print(f"⚠️ Model file not found: {model_path}")

# %%
# Merge human and model data
def merge_human_model(human_df, model_df):
    """Merge human and model data on QID."""
    human_df['qid'] = human_df['qid'].astype(str)
    
    # Handle different column names
    if 'qid' in model_df.columns:
        model_df['qid'] = model_df['qid'].astype(str)
    elif 'question_id' in model_df.columns:
        model_df['qid'] = model_df['question_id'].astype(str)
    elif 'index' in model_df.columns:
        model_df['qid'] = model_df['index'].astype(str)
    
    merged = pd.merge(
        human_df[['qid', 'mean_accuracy', 'mean_gt_similarity', 'mean_visual_similarity', 'mean_confidence']],
        model_df[['qid', 'correct']],
        on='qid',
        how='inner'
    )
    
    return merged

if os.path.exists(model_path):
    merged_df = merge_human_model(human_vqa_df, model_df)
    print(f"Merged data: {len(merged_df)} questions")
    print(merged_df.head())

# %% [markdown]
# ### Correlation: Model Accuracy vs Human GT Similarity

# %%
if os.path.exists(model_path) and len(merged_df) > 0:
    # Compute correlations
    r_gt, p_gt = stats.pearsonr(merged_df['correct'], merged_df['mean_gt_similarity'])
    r_acc, p_acc = stats.pearsonr(merged_df['correct'], merged_df['mean_accuracy'])
    
    print("Correlations:")
    print(f"  Model Accuracy vs Human GT Similarity: r = {r_gt:.4f} (p = {p_gt:.4f})")
    print(f"  Model Accuracy vs Human Accuracy: r = {r_acc:.4f} (p = {p_acc:.4f})")
    
    # Plot
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    
    # Plot 1: GT Similarity
    ax = axes[0]
    scatter = ax.scatter(
        merged_df['mean_gt_similarity'],
        merged_df['correct'],
        c=merged_df['mean_confidence'],
        alpha=0.5,
        cmap='viridis',
        s=50
    )
    
    # Trend line
    z = np.polyfit(merged_df['mean_gt_similarity'], merged_df['correct'], 1)
    p = np.poly1d(z)
    x_trend = np.linspace(merged_df['mean_gt_similarity'].min(), 
                         merged_df['mean_gt_similarity'].max(), 100)
    ax.plot(x_trend, p(x_trend), "r--", alpha=0.8, linewidth=2,
           label=f'y = {z[0]:.3f}x + {z[1]:.3f}')
    
    ax.set_xlabel('Human GT Similarity', fontsize=13)
    ax.set_ylabel('Model Accuracy', fontsize=13)
    ax.set_title(f'Model vs Human GT Similarity\nr = {r_gt:.4f}, p = {p_gt:.4f}',
                fontsize=14, fontweight='bold')
    ax.legend(fontsize=10)
    ax.grid(alpha=0.3)
    
    cbar = plt.colorbar(scatter, ax=ax)
    cbar.set_label('Human Confidence', fontsize=11)
    
    # Plot 2: Human Accuracy
    ax = axes[1]
    scatter = ax.scatter(
        merged_df['mean_accuracy'],
        merged_df['correct'],
        c=merged_df['mean_confidence'],
        alpha=0.5,
        cmap='viridis',
        s=50
    )
    
    # Trend line
    z = np.polyfit(merged_df['mean_accuracy'], merged_df['correct'], 1)
    p = np.poly1d(z)
    x_trend = np.linspace(merged_df['mean_accuracy'].min(), 
                         merged_df['mean_accuracy'].max(), 100)
    ax.plot(x_trend, p(x_trend), "r--", alpha=0.8, linewidth=2,
           label=f'y = {z[0]:.3f}x + {z[1]:.3f}')
    
    ax.set_xlabel('Human Accuracy', fontsize=13)
    ax.set_ylabel('Model Accuracy', fontsize=13)
    ax.set_title(f'Model vs Human Accuracy\nr = {r_acc:.4f}, p = {p_acc:.4f}',
                fontsize=14, fontweight='bold')
    ax.legend(fontsize=10)
    ax.grid(alpha=0.3)
    
    cbar = plt.colorbar(scatter, ax=ax)
    cbar.set_label('Human Confidence', fontsize=11)
    
    plt.tight_layout()
    plt.savefig(os.path.join(FIGURES_DIR, 'correlation_analysis.png'), 
                dpi=300, bbox_inches='tight')
    plt.show()
    
    print(f"\n✓ Saved: {os.path.join(FIGURES_DIR, 'correlation_analysis.png')}")

# %% [markdown]
# ---
#
# ## 3. Multimodal Gains Analysis
#
# **Research Question**: How much does visual information help model performance?
#
# We compute **Multimodal Gain (MG)** as:
# ```
# MG = Accuracy(baseline) - Accuracy(blind)
# ```
#
# We compare two blind conditions:
# - **blind**: No image, no special instruction
# - **inst_blind**: No image, with instruction about missing image

# %%
# Run comprehensive analysis
# !python evaluation/comprehensive_analysis.py \
    --human_dir {HUMAN_PROCESSED_DIR} \
    --model_dir {MODEL_DIR} \
    --finetuned_dir {FINETUNED_DIR} \
    --output_dir {OUTPUT_DIR} \
    --dataset vqa_1k

# %%
# Load results
with open(os.path.join(OUTPUT_DIR, 'comprehensive_analysis_summary.json')) as f:
    analysis_results = json.load(f)

print("✓ Loaded analysis results")
print("Available analyses:", list(analysis_results.keys()))

# %%
# Display multimodal gains
if 'multimodal_gains' in analysis_results:
    mg_df = pd.DataFrame(analysis_results['multimodal_gains'])
    
    print("=" * 80)
    print("MULTIMODAL GAINS (Baseline - Blind)")
    print("=" * 80)
    print(mg_df[['model', 'baseline_accuracy', 'blind_accuracy', 
                 'mg_blind', 'mg_blind_relative']].to_string(index=False))
    
    # Summary statistics
    print("\n" + "=" * 80)
    print("SUMMARY STATISTICS")
    print("=" * 80)
    print(f"Mean MG (blind): {mg_df['mg_blind'].mean():.4f} ± {mg_df['mg_blind'].std():.4f}")
    if 'mg_inst_blind' in mg_df.columns:
        print(f"Mean MG (inst_blind): {mg_df['mg_inst_blind'].mean():.4f} ± {mg_df['mg_inst_blind'].std():.4f}")

# %% [markdown]
# ---
#
# ## 4. Instruction Effects
#
# **Research Question**: Do instructions about missing images help performance?
#
# We compare:
# - **blind**: No image provided
# - **inst_blind**: No image + instruction: "No images are provided. For each question, imagine an appropriate image exists..."

# %%
# Display instruction effects
if 'instruction_effects' in analysis_results:
    inst_df = pd.DataFrame(analysis_results['instruction_effects'])
    
    print("=" * 80)
    print("INSTRUCTION EFFECTS (Inst+Blind - Blind)")
    print("=" * 80)
    print(inst_df[['model', 'blind_accuracy', 'inst_blind_accuracy', 
                   'instruction_effect', 'instruction_effect_relative']].to_string(index=False))
    
    # Summary
    print("\n" + "=" * 80)
    print("SUMMARY STATISTICS")
    print("=" * 80)
    print(f"Mean instruction effect: {inst_df['instruction_effect'].mean():.4f} ± {inst_df['instruction_effect'].std():.4f}")
    print(f"Positive effects: {(inst_df['instruction_effect'] > 0).sum()} / {len(inst_df)}")
    print(f"Negative effects: {(inst_df['instruction_effect'] < 0).sum()} / {len(inst_df)}")

# %% [markdown]
# ---
#
# ## 5. Pretrained vs Finetuned Comparison
#
# **Research Question**: Does finetuning on human blind responses improve performance?
#
# We compare accuracy distributions using:
# - **KS Test**: Tests if distributions are significantly different
# - **Mann-Whitney U**: Tests if medians are significantly different
# - **Cohen's d**: Measures effect size of improvement

# %%
# Display pretrained vs finetuned comparisons
if 'pretrained_vs_finetuned' in analysis_results:
    comparison_results = []
    
    for comparison_name, stats_dict in analysis_results['pretrained_vs_finetuned'].items():
        comparison_results.append(stats_dict)
    
    comp_df = pd.DataFrame(comparison_results)
    
    print("=" * 80)
    print("PRETRAINED VS FINETUNED")
    print("=" * 80)
    
    display_cols = ['pretrained_model', 'finetuned_model', 
                   'pretrained_mean', 'finetuned_mean', 
                   'improvement', 'improvement_relative', 
                   'cohens_d', 'ks_pvalue']
    
    # Format for display
    display_df = comp_df[display_cols].copy()
    display_df['pretrained_model'] = display_df['pretrained_model'].str.split('/').str[-1]
    display_df['finetuned_model'] = display_df['finetuned_model'].str.split('/').str[-1]
    
    print(display_df.to_string(index=False))
    
    # Summary
    print("\n" + "=" * 80)
    print("SUMMARY STATISTICS")
    print("=" * 80)
    print(f"Mean improvement: {comp_df['improvement'].mean():.4f} ± {comp_df['improvement'].std():.4f}")
    print(f"Mean relative improvement: {comp_df['improvement_relative'].mean():.2f}%")
    print(f"Mean Cohen's d: {comp_df['cohens_d'].mean():.3f}")
    print(f"Significant improvements (p < 0.05): {(comp_df['ks_pvalue'] < 0.05).sum()} / {len(comp_df)}")

# %% [markdown]
# ---
#
# ## 6. Paper Figures and Tables
#
# Generate publication-quality outputs.

# %% [markdown]
# ### Table 1: Human Performance Baseline

# %%
# Create summary table for paper
human_summary = pd.DataFrame([
    {
        'Task': 'VQA (Text)',
        'N Questions': vqa_stats['num_questions'],
        'N Responses': vqa_stats['total_responses'],
        'Mean Accuracy': f"{vqa_stats['mean_accuracy']:.3f}",
        'Mean Confidence': f"{vqa_stats['mean_confidence']:.3f}",
        'Corr(Conf, Acc)': f"{vqa_stats['correlation_conf_acc']:.3f}",
    },
    {
        'Task': 'Multiple Choice',
        'N Questions': mc_stats['num_questions'],
        'N Responses': mc_stats['total_responses'],
        'Mean Accuracy': f"{mc_stats['mean_accuracy']:.3f}",
        'Mean Confidence': f"{mc_stats['mean_confidence']:.3f}",
        'Corr(Conf, Acc)': f"{mc_stats['correlation_conf_acc']:.3f}",
    }
])

print("\nTable 1: Human Performance Baseline")
print(human_summary.to_latex(index=False))

# Save to file
with open(os.path.join(OUTPUT_DIR, 'table1_human_baseline.tex'), 'w') as f:
    f.write(human_summary.to_latex(index=False))
print(f"\n✓ Saved LaTeX table: {os.path.join(OUTPUT_DIR, 'table1_human_baseline.tex')}")

# %% [markdown]
# ### Table 2: Multimodal Gains

# %%
if 'multimodal_gains' in analysis_results:
    mg_table = mg_df[['model', 'baseline_accuracy', 'blind_accuracy', 
                      'mg_blind', 'mg_blind_relative']].copy()
    mg_table['model'] = mg_table['model'].str.split('/').str[-1]
    mg_table.columns = ['Model', 'Baseline', 'Blind', 'MG', 'MG (%)']
    
    print("\nTable 2: Multimodal Gains")
    print(mg_table.to_latex(index=False, float_format="%.3f"))
    
    with open(os.path.join(OUTPUT_DIR, 'table2_multimodal_gains.tex'), 'w') as f:
        f.write(mg_table.to_latex(index=False, float_format="%.3f"))
    print(f"\n✓ Saved LaTeX table: {os.path.join(OUTPUT_DIR, 'table2_multimodal_gains.tex')}")

# %% [markdown]
# ### Figure Summary

# %%
# List all generated figures
import glob

figures = glob.glob(os.path.join(FIGURES_DIR, '*.png'))
figures += glob.glob(os.path.join(OUTPUT_DIR, '*.png'))

print("=" * 80)
print("GENERATED FIGURES")
print("=" * 80)
for i, fig in enumerate(sorted(figures), 1):
    print(f"{i}. {os.path.basename(fig)}")

print(f"\nTotal: {len(figures)} figures")
print(f"Location: {FIGURES_DIR}")

# %% [markdown]
# ---
#
# ## Conclusions
#
# ### Key Findings:
#
# 1. **Human Baseline**: Humans achieve X% accuracy on blind VQA with Y confidence-accuracy correlation
#
# 2. **Model-Human Alignment**: Model accuracy correlates with human GT similarity (r = X, p < 0.001)
#
# 3. **Multimodal Gains**: Average MG of X% across models, showing importance of visual information
#
# 4. **Instruction Effects**: Instructions provide Y% improvement in blind conditions
#
# 5. **Finetuning Benefits**: Finetuned models show Z% improvement over pretrained (Cohen's d = W)
#
# ### Interpretation:
#
# - **GT vs Visual Similarity**: GT similarity measures alignment with all annotators, while visual similarity measures alignment with "oracle" humans who saw images. Higher correlation with visual similarity suggests models align better with informed humans.
#
# - **Multimodal Gains**: Large MG indicates strong dependence on visual information. Smaller MG suggests better blind reasoning.
#
# - **Instruction Effects**: Positive instruction effects show models benefit from explicit context about missing information.
#
# ---
