# %%
from datasets import load_dataset

dataset = load_dataset("lmarena-ai/VisionArena-Chat", trust_remote_code=True) # , split="train"
# Out:
# ...
#   warnings.warn(
# ...
# /home/work/.anaconda/envs/privacyovod_new_copy/lib/python3.10/site-packages/huggingface_hub/file_download.py:801: UserWarning: Not enough free disk space to download the file. The expected file size is: 1920.15 MB. The target location /home/work/main/Privacy/.tf_cache/huggingface/hub/datasets--lmarena-ai--VisionArena-Chat/blobs only has 0.00 MB free disk space.
#   warnings.warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 3
#       1 from datasets import load_dataset
# ----> 3 dataset = load_dataset("lmarena-ai/VisionArena-Chat", trust_remote_code=True) # , split="train"
#
# ...

# %%
dataset['public'][10]
# Out:
# {'system_instruction': 'You may only use information contained within the provided content block.',
#  'user_request': 'What benefits do nasal cannula have over non-rebreathe masks?',
# ...
